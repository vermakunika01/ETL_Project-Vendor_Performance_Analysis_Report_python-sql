# %% [markdown]
# **Importing Libraries**

# %%
import logging
import os
import time
from sqlalchemy import create_engine
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %% [markdown]
# **Data Ingestion**

# %%
# Get the current working directory
current_directory = os.getcwd()
print(f"The current working directory is: {current_directory}")
# Out:
# The current working directory is: C:\Users\nisha\Data Analysis Projects\ETL_Project

# %%
logging.basicConfig(
    filename = "logs/sql_ingestion_db_v2.log",
    level = logging.DEBUG, 
    format = "%(asctime)s - %(levelname)s - %(message)s",
    filemode = "a")

engine = create_engine('sqlite:///database.db')

def load_data(): 
    start = time.time()
    for file in os.listdir('data'): 
        if ".csv" in file: 
            df = pd.read_csv('data/'+ file) 
            print(file, " file_shape: " ,df.shape)
            logging.info(f'Ingesting {file} in db')
            df.to_sql(file[:-4], engine, if_exists='replace', index = False) 
    end = time.time()
    total_time = (end - start)/60
    logging.info('--------------Ingestion Complete------------')
    logging.info(f'\nTotal Time Taken: {total_time} minutes')

if __name__ == '__main__':
    load_data()
# Out:
# begin_inventory.csv  file_shape:  (8000, 9)
# end_inventory.csv  file_shape:  (8000, 9)
# purchases.csv  file_shape:  (32300, 16)
# purchase_prices.csv  file_shape:  (12000, 9)
# sales.csv  file_shape:  (95050, 14)
# vendor_invoice.csv  file_shape:  (5200, 10)

# %% [markdown]
# **Data Loading Verification**

# %%
tables = pd.read_sql_query("SELECT name, type FROM sqlite_master WHERE type = 'table' LIMIT 10", engine)
tables
# Out:
#               name   type
# 0  begin_inventory  table
# 1    end_inventory  table
# 2        purchases  table
# 3  purchase_prices  table
# 4            sales  table
# 5   vendor_invoice  table

# %% [markdown]
# **Data Aggregation + Data Cleaning**

# %%
for table in tables['name']:   # 'name' should be in inverted commas as we are referring to a dataframe column
    print('Table Name:', table, '\nCount of records:', pd.read_sql_query(f" SELECT count(*) as count FROM {table}", engine)['count'].iloc[0])
# Out:
# Table Name: begin_inventory
# Count of records: 8000
# Table Name: end_inventory
# Count of records: 8000
# Table Name: purchases
# Count of records: 32300
# Table Name: purchase_prices
# Count of records: 12000
# Table Name: sales
# Count of records: 95050
# Table Name: vendor_invoice
# Count of records: 5200

# %% [markdown]
# **Displaying Tables**

# %%
for table in tables['name']:   # 'name' should be in inverted commas as we are referring to a dictionary (sqlite_master) key
    print('-'*50, table, '-'*50)
    print("Count of Records: ", pd.read_sql_query(f"SELECT count(*) as count FROM {table}", engine)['count'].iloc[0])
    display(pd.read_sql_query(f"SELECT * FROM {table} LIMIT 5", engine))   # {table} in f-string uses the value stored in the table variable, using only 'table' will give an error
# Out:
# -------------------------------------------------- begin_inventory --------------------------------------------------
# Count of Records:  8000
#    InventoryId    Store            City     Brand  Description    Size  \
# 0       100000  Store_8        Toddfurt  Brand_21   Product_71  Medium
# 1       100001  Store_9      Port Shawn   Brand_3   Product_87   Small
# 2       100002  Store_9        Lisaside   Brand_2  Product_112   Small
# 3       100003  Store_5  South Danielle  Brand_12   Product_31   Small
# 4       100004  Store_8        Toddfurt  Brand_24  Product_179   Large
#
#    onHand   Price     startDate
# 0     343   82.44  Jun 24, 2024
# 1     241  157.82    2024-01-17
# 2     544  251.95    05/09/2024
# 3     323  156.20      24/08/24
# 4      31  193.32    06/06/2024
# -------------------------------------------------- end_inventory --------------------------------------------------
# Count of Records:  8000
#    InventoryId     Store               City     Brand  Description    Size  \
# 0       200000   Store_4  Lake Davidchester  Brand_19  Product_124  Medium
# 1       200001  Store_13           New Dawn   Brand_6  Product_140   Large
# 2       200002   Store_9           Loriland  Brand_22   Product_67   Large
# 3       200003  Store_15     South Danielle  Brand_25   Product_52   Large
# 4       200004   Store_9         Shanemouth  Brand_17   Product_23   Small
#
#    onHand   Price       endDate
# 0     159  173.20  Aug 16, 2024
# 1     588  232.66    10/11/2024
# 2     556  113.63  Feb 23, 2024
# 3     360  241.09  Jul 17, 2024
# 4     642  285.39    2024-01-04
# -------------------------------------------------- purchases --------------------------------------------------
# Count of Records:  32300
#    InventoryId     Store     Brand  Description   Size VendorNumber  \
# 0       300000  Store_17   brand_6   Product_53  Large         V038
# 1       300001   Store_4   Brand 7  Product_136  Small         V009
# 2       300002  Store_12  Brand_18   Product_51  Small         V015
# 3       300003   Store_9  brand_19  Product_131  Large         V014
# 4       300004  Store_16   Brand_7  Product_159  Large         V009
#
#                  VendorName    PONumber        PODate ReceivingDate  \
# 0               Shannon Ltd  PO-9557-bh    04/03/2024    12/13/2024
# 1             Jackson Group  PO-4140-Bm    2024-06-09  Oct 14, 2024
# 2         Wolfe-Murillo Ltd  PO-1722-ls  May 14, 2024    05/29/2024
# 3  Carroll, Price and Perez  PO-8521-gH    2024-04-20    2024-03-08
# 4             Jackson Group  PO-8073-SP    07/25/2024    2024-02-11
#
#     InvoiceDate       PayDate  PurchasePrice  Quantity Classification  \
# 0  Jan 23, 2024      17/07/24         174.17      74.0              A
# 1    08/27/2024    2024-11-24         165.21      53.0              A
# 2  Jan 28, 2024    05/26/2024         166.58     168.0              A
# 3    2024-07-14  Jul 23, 2024         180.35     148.0              C
# 4      18/03/24      18/01/24         191.35     420.0              B
#
#     Dollars
# 0  12888.58
# 1   8756.13
# 2  27985.44
# 3  26691.80
# 4  80367.00
# -------------------------------------------------- purchase_prices --------------------------------------------------
# Count of Records:  12000
#       Brand  Description   Price    Size  Volume Classification  \
# 0   Brand_7  Product_143  111.24  Medium       6              A
# 1  Brand_20  Product_169  226.35   Large      12              C
# 2  Brand_15  Product_115  252.93   Small      12              C
# 3  Brand_11  Product_109  255.70   Small       6              B
# 4   Brand_8   Product_90  254.02  Medium      24              C
#
#    PurchasePrice VendorNumber                 VendorName
# 0         125.27         V018               Long-Roberts
# 1         223.92         V013              Jackson Group
# 2         174.18         V031                 Harris PLC
# 3         222.85         V003  Pratt, Parrish and Reilly
# 4         242.18         V030           Banks-Montgomery
# -------------------------------------------------- sales --------------------------------------------------
# Count of Records:  95050
#    InventoryId     Store     Brand  Description    Size  SalesQuantity  \
# 0       400000  Store_11   brand_9   Product_94   Large          352.0
# 1       400001  Store_14  brand_12   Product_29   Small           58.0
# 2       400002   Store_3  Brand_21  Product_119  Medium           57.0
# 3       400003   Store_1  Brand 25  Product_163   Large          354.0
# 4       400004  Store_16     BRD-3   Product_18  Medium          334.0
#
#    SalesPrice     SalesDate  Volume Classification VendorNo  \
# 0      211.36    06/09/2024    5292              C     V004
# 1      244.67    03/10/2024    8851              B     V017
# 2      200.76  Dec 15, 2024    7843              C     V031
# 3      228.12  Jan 11, 2024    1376              C     V026
# 4      221.32  May 29, 2024    7600              C     V005
#
#                       VendorName  SalesDollars  ExciseTax
# 0                  Keith-Sanchez      74398.72    3943.99
# 1                Harrington-Gray      14190.86     837.90
# 2                  Kane_and_Sons      11443.32    1437.55
# 3  FUENTES, RICHARDS AND JOHNSON      80754.48   11208.05
# 4                    cordova llc      73920.88    9542.55
# -------------------------------------------------- vendor_invoice --------------------------------------------------
# Count of Records:  5200
#   VendorNumber         VendorName  Quantity      Dollars    Freight  \
# 0         V039         Lara_Group  212337.0  36910458.55  273137.39
# 1         V029        Mcdaniel-Le  199724.0  34347016.44  501466.44
# 2         V015  Wolfe-Murillo Ltd  217758.0  37421596.92  508933.72
# 3         V008       MCDONALD LTD  207022.0  35699470.20  560481.68
# 4         V021   BANKS-MONTGOMERY  199468.0  34367702.77  457090.45
#
#     InvoiceDate        PODate       PayDate PONumber  Approval
# 0  Apr 08, 2024    07/26/2024    2024-10-28  PO-8697   Pending
# 1    2024-05-30    03/21/2024    09/07/2024  PO-1759  Approved
# 2      30/04/24  Jan 30, 2024  Dec 09, 2024  PO-7385  Approved
# 3  Mar 28, 2024  Jan 30, 2024  Feb 04, 2024  PO-0551  Approved
# 4      28/12/24  Oct 31, 2024      17/09/24  PO-5749  Approved

# %% [markdown]
# **Data Cleaning -- Date Formatting**

# %%
#LOADING TABLES INTO PYTHON MEMORY AS DATAFRAMES - Python has rihcer datetime parsing/ formatting functions

#Approach 1: for table in tables['name']: name = pd.read_sql_query(f"SELECT * FROM {table}", engine) -- But this is helpful when the operations are being performed WHILE running the loop itself

#Approach 2:
dfs = {df: pd.read_sql_query(f"SELECT * FROM {df}", engine) for df in tables['name']}

# %%
#CONVERTING TO DATETIME FORMAT 

#dfs['begin_inventory']['startDate'].apply(type).value_counts()  # chaining keys of dictionary dfs to reference each table

dfs['begin_inventory']['startDate_clean'] = pd.to_datetime(dfs['begin_inventory']['startDate'],format='mixed', errors='coerce',dayfirst=True)
dfs['end_inventory']['endDate_clean'] = pd.to_datetime(dfs['end_inventory']['endDate'],format='mixed', errors='coerce',dayfirst=True)
dfs['purchases']['ReceivingDate_clean'] = pd.to_datetime(dfs['purchases']['ReceivingDate'],format='mixed', errors='coerce',dayfirst=True)
dfs['purchases']['InvoiceDate_clean'] = pd.to_datetime(dfs['purchases']['InvoiceDate'],format='mixed', errors='coerce',dayfirst=True)
dfs['purchases']['PayDate_clean'] = pd.to_datetime(dfs['purchases']['PayDate'],format='mixed', errors='coerce',dayfirst=True)
dfs['vendor_invoice']['PayDate_clean'] = pd.to_datetime(dfs['purchases']['PayDate'],format='mixed', errors='coerce',dayfirst=True)
dfs['vendor_invoice']['PODate_clean'] = pd.to_datetime(dfs['purchases']['PODate'],format='mixed', errors='coerce',dayfirst=True)

# %% [markdown]
# **Data Cleaning - Standardizing Text Columns**

# %%
## REMOVING TRAILING SPACES FROM ALL TEXT COLUMNS

for name, df in dfs.items():
    for col_name in df.columns:
        if df[col_name].dtype == 'object':
            df[col_name] = df[col_name].astype(str).str.strip()

# Other Approach using isinstance() method: 
#for name, df in dfs.items():
#    for col_name in df.columns:    
#        if df[col_name].apply(lambda x: isinstance(x, str)).all():
#            df[col_name].str.strip()

#-----------------------------------------------------------------

# %%
## CHECKING THE ENTRIES IN THE TEXT COLUMNS TO IDENTIFY INCONSISTENCIES

for name, df in dfs.items():
    for col_name in df.columns:
        if  df[col_name].dtype == 'object':
            print(f"-----{name}-----:----{col_name}----")
            print(df[col_name].sort_values().unique(),"\n")

## ONLY WORKING WITH COLUMNS THAT ARE IMPORTANT FOR ANALYSIS
for name, df in dfs.items():
    for col_name in df.columns:
        if (df[col_name].dtype == 'object') & (col_name in ['City','Brand','VendorName']):
            print(f"-----{name}-----:----{col_name}----")
            print(df[col_name].sort_values().unique(),"\n")

#----------------------------------------------------------------
# Out:
# -----begin_inventory-----:----Store----
# ['Store_1' 'Store_10' 'Store_11' 'Store_12' 'Store_13' 'Store_14'
#  'Store_15' 'Store_16' 'Store_17' 'Store_18' 'Store_2' 'Store_3' 'Store_4'
#  'Store_5' 'Store_6' 'Store_7' 'Store_8' 'Store_9']
#
# -----begin_inventory-----:----City----
# ['Adambury' 'Crossshire' 'East Jessicastad' 'Lake Davidchester'
#  'Lake Ryanmouth' 'Lisaside' 'Loriland' 'New Dawn' 'Port Brett'
#  'Port Joshua' 'Port Shawn' 'Shanemouth' 'South Danielle' 'South Peter'
#  'South Victorberg' 'Stevenmouth' 'Toddfurt' 'West Amber']
#
# -----begin_inventory-----:----Brand----
# ['Brand_1' 'Brand_10' 'Brand_11' 'Brand_12' 'Brand_13' 'Brand_14'
#  'Brand_15' 'Brand_16' 'Brand_17' 'Brand_18' 'Brand_19' 'Brand_2'
#  'Brand_20' 'Brand_21' 'Brand_22' 'Brand_23' 'Brand_24' 'Brand_25'
#  'Brand_3' 'Brand_4' 'Brand_5' 'Brand_6' 'Brand_7' 'Brand_8' 'Brand_9'
#  'brand_1' 'brand_10' 'brand_11' 'brand_12' 'brand_13' 'brand_14'
#  'brand_15' 'brand_16' 'brand_18' 'brand_19' 'brand_2' 'brand_21'
#  'brand_22' 'brand_23' 'brand_24' 'brand_25' 'brand_3' 'brand_4' 'brand_5'
#  'brand_6' 'brand_7' 'brand_8' 'brand_9']
#
# -----begin_inventory-----:----Description----
# ['None' 'Product_1' 'Product_10' 'Product_100' 'Product_101' 'Product_102'
#  'Product_103' 'Product_104' 'Product_105' 'Product_106' 'Product_107'
#  'Product_108' 'Product_109' 'Product_11' 'Product_110' 'Product_111'
#  'Product_112' 'Product_113' 'Product_114' 'Product_115' 'Product_116'
#  'Product_117' 'Product_118' 'Product_119' 'Product_12' 'Product_120'
#  'Product_121' 'Product_122' 'Product_123' 'Product_124' 'Product_125'
#  'Product_126' 'Product_127' 'Product_128' 'Product_129' 'Product_13'
#  'Product_130' 'Product_131' 'Product_132' 'Product_133' 'Product_134'
#  'Product_135' 'Product_136' 'Product_137' 'Product_138' 'Product_139'
#  'Product_14' 'Product_140' 'Product_141' 'Product_142' 'Product_143'
#  'Product_144' 'Product_145' 'Product_146' 'Product_147' 'Product_148'
#  'Product_149' 'Product_15' 'Product_150' 'Product_151' 'Product_152'
#  'Product_153' 'Product_154' 'Product_155' 'Product_156' 'Product_157'
#  'Product_158' 'Product_159' 'Product_16' 'Product_160' 'Product_161'
#  'Product_162' 'Product_163' 'Product_164' 'Product_165' 'Product_166'
#  'Product_167' 'Product_168' 'Product_169' 'Product_17' 'Product_170'
#  'Product_171' 'Product_172' 'Product_173' 'Product_174' 'Product_175'
#  'Product_176' 'Product_177' 'Product_178' 'Product_179' 'Product_18'
#  'Product_180' 'Product_19' 'Product_2' 'Product_20' 'Product_21'
#  'Product_22' 'Product_23' 'Product_24' 'Product_25' 'Product_26'
#  'Product_27' 'Product_28' 'Product_29' 'Product_3' 'Product_30'
#  'Product_31' 'Product_32' 'Product_33' 'Product_34' 'Product_35'
#  'Product_36' 'Product_37' 'Product_38' 'Product_39' 'Product_4'
#  'Product_40' 'Product_41' 'Product_42' 'Product_43' 'Product_44'
#  'Product_45' 'Product_46' 'Product_47' 'Product_48' 'Product_49'
#  'Product_5' 'Product_50' 'Product_51' 'Product_52' 'Product_53'
#  'Product_54' 'Product_55' 'Product_56' 'Product_57' 'Product_58'
#  'Product_59' 'Product_6' 'Product_60' 'Product_61' 'Product_62'
#  'Product_63' 'Product_64' 'Product_65' 'Product_66' 'Product_67'
#  'Product_68' 'Product_69' 'Product_7' 'Product_70' 'Product_71'
#  'Product_72' 'Product_73' 'Product_74' 'Product_75' 'Product_76'
#  'Product_77' 'Product_78' 'Product_79' 'Product_8' 'Product_80'
#  'Product_81' 'Product_82' 'Product_83' 'Product_84' 'Product_85'
#  'Product_86' 'Product_87' 'Product_88' 'Product_89' 'Product_9'
#  'Product_90' 'Product_91' 'Product_92' 'Product_93' 'Product_94'
#  'Product_95' 'Product_96' 'Product_97' 'Product_98' 'Product_99']
#
# -----begin_inventory-----:----Size----
# ['Large' 'Medium' 'Small']
#
# -----begin_inventory-----:----startDate----
# ['01/01/2024' '01/01/24' '01/02/2024' ... 'Sep 28, 2024' 'Sep 29, 2024'
#  'Sep 30, 2024']
#
# -----end_inventory-----:----Store----
# ['Store_1' 'Store_10' 'Store_11' 'Store_12' 'Store_13' 'Store_14'
#  'Store_15' 'Store_16' 'Store_17' 'Store_18' 'Store_2' 'Store_3' 'Store_4'
#  'Store_5' 'Store_6' 'Store_7' 'Store_8' 'Store_9']
#
# -----end_inventory-----:----City----
# ['Adambury' 'Crossshire' 'East Jessicastad' 'Lake Davidchester'
#  'Lake Ryanmouth' 'Lisaside' 'Loriland' 'New Dawn' 'Port Brett'
#  'Port Joshua' 'Port Shawn' 'Shanemouth' 'South Danielle' 'South Peter'
#  'South Victorberg' 'Stevenmouth' 'Toddfurt' 'West Amber']
#
# -----end_inventory-----:----Brand----
# ['Brand_1' 'Brand_10' 'Brand_11' 'Brand_12' 'Brand_13' 'Brand_14'
#  'Brand_15' 'Brand_16' 'Brand_17' 'Brand_18' 'Brand_19' 'Brand_2'
#  'Brand_20' 'Brand_21' 'Brand_22' 'Brand_23' 'Brand_24' 'Brand_25'
#  'Brand_3' 'Brand_4' 'Brand_5' 'Brand_6' 'Brand_7' 'Brand_8' 'Brand_9']
#
# -----end_inventory-----:----Description----
# ['Product_1' 'Product_10' 'Product_100' 'Product_101' 'Product_102'
#  'Product_103' 'Product_104' 'Product_105' 'Product_106' 'Product_107'
#  'Product_108' 'Product_109' 'Product_11' 'Product_110' 'Product_111'
#  'Product_112' 'Product_113' 'Product_114' 'Product_115' 'Product_116'
#  'Product_117' 'Product_118' 'Product_119' 'Product_12' 'Product_120'
#  'Product_121' 'Product_122' 'Product_123' 'Product_124' 'Product_125'
#  'Product_126' 'Product_127' 'Product_128' 'Product_129' 'Product_13'
#  'Product_130' 'Product_131' 'Product_132' 'Product_133' 'Product_134'
#  'Product_135' 'Product_136' 'Product_137' 'Product_138' 'Product_139'
#  'Product_14' 'Product_140' 'Product_141' 'Product_142' 'Product_143'
#  'Product_144' 'Product_145' 'Product_146' 'Product_147' 'Product_148'
#  'Product_149' 'Product_15' 'Product_150' 'Product_151' 'Product_152'
#  'Product_153' 'Product_154' 'Product_155' 'Product_156' 'Product_157'
#  'Product_158' 'Product_159' 'Product_16' 'Product_160' 'Product_161'
#  'Product_162' 'Product_163' 'Product_164' 'Product_165' 'Product_166'
#  'Product_167' 'Product_168' 'Product_169' 'Product_17' 'Product_170'
#  'Product_171' 'Product_172' 'Product_173' 'Product_174' 'Product_175'
#  'Product_176' 'Product_177' 'Product_178' 'Product_179' 'Product_18'
#  'Product_180' 'Product_19' 'Product_2' 'Product_20' 'Product_21'
#  'Product_22' 'Product_23' 'Product_24' 'Product_25' 'Product_26'
#  'Product_27' 'Product_28' 'Product_29' 'Product_3' 'Product_30'
#  'Product_31' 'Product_32' 'Product_33' 'Product_34' 'Product_35'
#  'Product_36' 'Product_37' 'Product_38' 'Product_39' 'Product_4'
#  'Product_40' 'Product_41' 'Product_42' 'Product_43' 'Product_44'
#  'Product_45' 'Product_46' 'Product_47' 'Product_48' 'Product_49'
#  'Product_5' 'Product_50' 'Product_51' 'Product_52' 'Product_53'
#  'Product_54' 'Product_55' 'Product_56' 'Product_57' 'Product_58'
#  'Product_59' 'Product_6' 'Product_60' 'Product_61' 'Product_62'
#  'Product_63' 'Product_64' 'Product_65' 'Product_66' 'Product_67'
#  'Product_68' 'Product_69' 'Product_7' 'Product_70' 'Product_71'
#  'Product_72' 'Product_73' 'Product_74' 'Product_75' 'Product_76'
#  'Product_77' 'Product_78' 'Product_79' 'Product_8' 'Product_80'
#  'Product_81' 'Product_82' 'Product_83' 'Product_84' 'Product_85'
#  'Product_86' 'Product_87' 'Product_88' 'Product_89' 'Product_9'
#  'Product_90' 'Product_91' 'Product_92' 'Product_93' 'Product_94'
#  'Product_95' 'Product_96' 'Product_97' 'Product_98' 'Product_99']
#
# -----end_inventory-----:----Size----
# ['Large' 'Medium' 'Small']
#
# -----end_inventory-----:----endDate----
# ['01/01/2024' '01/01/24' '01/02/2024' ... 'Sep 28, 2024' 'Sep 29, 2024'
#  'Sep 30, 2024']
#
# -----purchases-----:----Store----
# ['Store_1' 'Store_10' 'Store_11' 'Store_12' 'Store_13' 'Store_14'
#  'Store_15' 'Store_16' 'Store_17' 'Store_18' 'Store_2' 'Store_3' 'Store_4'
#  'Store_5' 'Store_6' 'Store_7' 'Store_8' 'Store_9']
#
# -----purchases-----:----Brand----
# ['BRD-1' 'BRD-10' 'BRD-11' 'BRD-12' 'BRD-13' 'BRD-14' 'BRD-15' 'BRD-16'
#  'BRD-17' 'BRD-18' 'BRD-19' 'BRD-2' 'BRD-20' 'BRD-21' 'BRD-22' 'BRD-23'
#  'BRD-24' 'BRD-25' 'BRD-3' 'BRD-4' 'BRD-5' 'BRD-6' 'BRD-7' 'BRD-8' 'BRD-9'
#  'Brand 1' 'Brand 10' 'Brand 11' 'Brand 12' 'Brand 13' 'Brand 14'
#  'Brand 15' 'Brand 16' 'Brand 17' 'Brand 18' 'Brand 19' 'Brand 2'
#  'Brand 20' 'Brand 21' 'Brand 22' 'Brand 23' 'Brand 24' 'Brand 25'
#  'Brand 3' 'Brand 4' 'Brand 5' 'Brand 6' 'Brand 7' 'Brand 8' 'Brand 9'
#  'Brand_1' 'Brand_10' 'Brand_11' 'Brand_12' 'Brand_13' 'Brand_14'
#  'Brand_15' 'Brand_16' 'Brand_17' 'Brand_18' 'Brand_19' 'Brand_2'
#  'Brand_20' 'Brand_21' 'Brand_22' 'Brand_23' 'Brand_24' 'Brand_25'
#  'Brand_3' 'Brand_4' 'Brand_5' 'Brand_6' 'Brand_7' 'Brand_8' 'Brand_9'
#  'brand_1' 'brand_10' 'brand_11' 'brand_12' 'brand_13' 'brand_14'
#  'brand_15' 'brand_16' 'brand_17' 'brand_18' 'brand_19' 'brand_2'
#  'brand_20' 'brand_21' 'brand_22' 'brand_23' 'brand_24' 'brand_25'
#  'brand_3' 'brand_4' 'brand_5' 'brand_6' 'brand_7' 'brand_8' 'brand_9']
#
# -----purchases-----:----Description----
# ['Product_1' 'Product_10' 'Product_100' 'Product_101' 'Product_102'
#  'Product_103' 'Product_104' 'Product_105' 'Product_106' 'Product_107'
#  'Product_108' 'Product_109' 'Product_11' 'Product_110' 'Product_111'
#  'Product_112' 'Product_113' 'Product_114' 'Product_115' 'Product_116'
#  'Product_117' 'Product_118' 'Product_119' 'Product_12' 'Product_120'
#  'Product_121' 'Product_122' 'Product_123' 'Product_124' 'Product_125'
#  'Product_126' 'Product_127' 'Product_128' 'Product_129' 'Product_13'
#  'Product_130' 'Product_131' 'Product_132' 'Product_133' 'Product_134'
#  'Product_135' 'Product_136' 'Product_137' 'Product_138' 'Product_139'
#  'Product_14' 'Product_140' 'Product_141' 'Product_142' 'Product_143'
#  'Product_144' 'Product_145' 'Product_146' 'Product_147' 'Product_148'
#  'Product_149' 'Product_15' 'Product_150' 'Product_151' 'Product_152'
#  'Product_153' 'Product_154' 'Product_155' 'Product_156' 'Product_157'
#  'Product_158' 'Product_159' 'Product_16' 'Product_160' 'Product_161'
#  'Product_162' 'Product_163' 'Product_164' 'Product_165' 'Product_166'
#  'Product_167' 'Product_168' 'Product_169' 'Product_17' 'Product_170'
#  'Product_171' 'Product_172' 'Product_173' 'Product_174' 'Product_175'
#  'Product_176' 'Product_177' 'Product_178' 'Product_179' 'Product_18'
#  'Product_180' 'Product_19' 'Product_2' 'Product_20' 'Product_21'
#  'Product_22' 'Product_23' 'Product_24' 'Product_25' 'Product_26'
#  'Product_27' 'Product_28' 'Product_29' 'Product_3' 'Product_30'
#  'Product_31' 'Product_32' 'Product_33' 'Product_34' 'Product_35'
#  'Product_36' 'Product_37' 'Product_38' 'Product_39' 'Product_4'
#  'Product_40' 'Product_41' 'Product_42' 'Product_43' 'Product_44'
#  'Product_45' 'Product_46' 'Product_47' 'Product_48' 'Product_49'
#  'Product_5' 'Product_50' 'Product_51' 'Product_52' 'Product_53'
#  'Product_54' 'Product_55' 'Product_56' 'Product_57' 'Product_58'
#  'Product_59' 'Product_6' 'Product_60' 'Product_61' 'Product_62'
#  'Product_63' 'Product_64' 'Product_65' 'Product_66' 'Product_67'
#  'Product_68' 'Product_69' 'Product_7' 'Product_70' 'Product_71'
#  'Product_72' 'Product_73' 'Product_74' 'Product_75' 'Product_76'
#  'Product_77' 'Product_78' 'Product_79' 'Product_8' 'Product_80'
#  'Product_81' 'Product_82' 'Product_83' 'Product_84' 'Product_85'
#  'Product_86' 'Product_87' 'Product_88' 'Product_89' 'Product_9'
#  'Product_90' 'Product_91' 'Product_92' 'Product_93' 'Product_94'
#  'Product_95' 'Product_96' 'Product_97' 'Product_98' 'Product_99']
#
# -----purchases-----:----Size----
# ['Large' 'Medium' 'Small']
#
# -----purchases-----:----VendorNumber----
# ['V001' 'V002' 'V003' 'V004' 'V005' 'V006' 'V007' 'V008' 'V009' 'V010'
#  'V011' 'V012' 'V013' 'V014' 'V015' 'V016' 'V017' 'V018' 'V019' 'V020'
#  'V021' 'V022' 'V023' 'V024' 'V025' 'V026' 'V027' 'V028' 'V029' 'V030'
#  'V031' 'V032' 'V033' 'V034' 'V035' 'V036' 'V037' 'V038' 'V039' 'V040']
#
# -----purchases-----:----VendorName----
# ['ACEVEDO, JOHNSON AND HIGGINS' 'BANKS-MONTGOMERY'
#  'BARTLETT, COLEMAN AND GRAY LTD' 'Bartlett, Coleman and Gray Ltd'
#  'CARROLL, PRICE AND PEREZ' 'CORDOVA LLC' 'CORTEZ INC'
#  'Carroll, Price and Perez' 'Cortez Inc' 'FUENTES, RICHARDS AND JOHNSON'
#  'GAINES-MCKINNEY LTD' 'GRANT-ADAMS LTD' 'GRIFFIN-YORK'
#  'Gaines-Mckinney Ltd' 'Grant-Adams Ltd' 'HARRINGTON-GRAY' 'HARRIS_PLC'
#  'HICKS-JACKSON' 'HILL LLC' 'Harrington-Gray' 'Harris_PLC' 'Hill LLC'
#  'JACKSON GROUP' 'JOHNSON, CAREY AND NICHOLS' 'Jackson Group'
#  'Johnson, Carey and Nichols' 'KANE_AND_SONS' 'KEITH-SANCHEZ'
#  'Kane_and_Sons' 'Keith-Sanchez' 'LARA_GROUP' 'LONG-ROBERTS' 'Lara_Group'
#  'Long-Roberts' 'MARTINEZ, JONES AND OSBORNE'
#  'MCCARTHY,_DAVIS_AND_MCCORMICK' 'MCDANIEL-LE' 'MCDONALD LTD'
#  'MCLAUGHLIN-SMITH' 'Martinez, Jones and Osborne'
#  'Mccarthy,_Davis_and_Mccormick' 'Mcdaniel-Le' 'Mclaughlin-Smith'
#  'NORRIS-ORTEGA' 'Norris-Ortega' 'PARKER-ROGERS'
#  'PRATT, PARRISH AND REILLY' 'Pratt, Parrish and Reilly'
#  'REESE, BAKER AND SUTTON LTD' 'RODRIGUEZ-NGUYEN LTD'
#  'Reese, Baker and Sutton Ltd' 'Rodriguez-Nguyen Ltd'
#  'SCHROEDER, PAYNE AND HOOPER' 'SHANNON LTD' 'SHAW, BROWN AND FERGUSON'
#  'Schroeder, Payne and Hooper' 'Shannon Ltd' 'Shaw, Brown and Ferguson'
#  'THOMPSON-EDWARDS' 'Thompson-Edwards' 'VALDEZ GROUP' 'Valdez Group'
#  'WADE, WILLIAMS AND NICHOLS' 'WATTS GROUP' 'WILLIS AND SONS LTD'
#  'WOLFE-MURILLO LTD' 'Willis and Sons Ltd' 'Wolfe-Murillo Ltd'
#  'cordova llc' 'hicks-jackson' 'parker-rogers']
#
# -----purchases-----:----PONumber----
# ['PO-0000-cy' 'PO-0000-dP' 'PO-0000-jR' ... 'PO-9999-ew' 'PO-9999-lf'
#  'PO-9999-xR']
#
# -----purchases-----:----PODate----
# ['01/01/2024' '01/01/24' '01/02/2024' ... 'Sep 28, 2024' 'Sep 29, 2024'
#  'Sep 30, 2024']
#
# -----purchases-----:----ReceivingDate----
# ['01/01/2024' '01/01/24' '01/02/2024' ... 'Sep 28, 2024' 'Sep 29, 2024'
#  'Sep 30, 2024']
#
# -----purchases-----:----InvoiceDate----
# ['01/01/2024' '01/01/24' '01/02/2024' ... 'Sep 28, 2024' 'Sep 29, 2024'
#  'Sep 30, 2024']
#
# -----purchases-----:----PayDate----
# ['01/01/2024' '01/01/24' '01/02/2024' ... 'Sep 28, 2024' 'Sep 29, 2024'
#  'Sep 30, 2024']
#
# -----purchases-----:----Classification----
# ['A' 'B' 'C']
#
# -----purchase_prices-----:----Brand----
# ['Brand_1' 'Brand_10' 'Brand_11' 'Brand_12' 'Brand_13' 'Brand_14'
#  'Brand_15' 'Brand_16' 'Brand_17' 'Brand_18' 'Brand_19' 'Brand_2'
#  'Brand_20' 'Brand_21' 'Brand_22' 'Brand_23' 'Brand_24' 'Brand_25'
#  'Brand_3' 'Brand_4' 'Brand_5' 'Brand_6' 'Brand_7' 'Brand_8' 'Brand_9'
#  'brand_1' 'brand_10' 'brand_11' 'brand_13' 'brand_15' 'brand_16'
#  'brand_17' 'brand_18' 'brand_19' 'brand_2' 'brand_20' 'brand_21'
#  'brand_23' 'brand_24' 'brand_25' 'brand_3' 'brand_4' 'brand_5' 'brand_6'
#  'brand_7' 'brand_9']
#
# -----purchase_prices-----:----Description----
# ['Product_1' 'Product_10' 'Product_100' 'Product_101' 'Product_102'
#  'Product_103' 'Product_104' 'Product_105' 'Product_106' 'Product_107'
#  'Product_108' 'Product_109' 'Product_11' 'Product_110' 'Product_111'
#  'Product_112' 'Product_113' 'Product_114' 'Product_115' 'Product_116'
#  'Product_117' 'Product_118' 'Product_119' 'Product_12' 'Product_120'
#  'Product_121' 'Product_122' 'Product_123' 'Product_124' 'Product_125'
#  'Product_126' 'Product_127' 'Product_128' 'Product_129' 'Product_13'
#  'Product_130' 'Product_131' 'Product_132' 'Product_133' 'Product_134'
#  'Product_135' 'Product_136' 'Product_137' 'Product_138' 'Product_139'
#  'Product_14' 'Product_140' 'Product_141' 'Product_142' 'Product_143'
#  'Product_144' 'Product_145' 'Product_146' 'Product_147' 'Product_148'
#  'Product_149' 'Product_15' 'Product_150' 'Product_151' 'Product_152'
#  'Product_153' 'Product_154' 'Product_155' 'Product_156' 'Product_157'
#  'Product_158' 'Product_159' 'Product_16' 'Product_160' 'Product_161'
#  'Product_162' 'Product_163' 'Product_164' 'Product_165' 'Product_166'
#  'Product_167' 'Product_168' 'Product_169' 'Product_17' 'Product_170'
#  'Product_171' 'Product_172' 'Product_173' 'Product_174' 'Product_175'
#  'Product_176' 'Product_177' 'Product_178' 'Product_179' 'Product_18'
#  'Product_180' 'Product_19' 'Product_2' 'Product_20' 'Product_21'
#  'Product_22' 'Product_23' 'Product_24' 'Product_25' 'Product_26'
#  'Product_27' 'Product_28' 'Product_29' 'Product_3' 'Product_30'
#  'Product_31' 'Product_32' 'Product_33' 'Product_34' 'Product_35'
#  'Product_36' 'Product_37' 'Product_38' 'Product_39' 'Product_4'
#  'Product_40' 'Product_41' 'Product_42' 'Product_43' 'Product_44'
#  'Product_45' 'Product_46' 'Product_47' 'Product_48' 'Product_49'
#  'Product_5' 'Product_50' 'Product_51' 'Product_52' 'Product_53'
#  'Product_54' 'Product_55' 'Product_56' 'Product_57' 'Product_58'
#  'Product_59' 'Product_6' 'Product_60' 'Product_61' 'Product_62'
#  'Product_63' 'Product_64' 'Product_65' 'Product_66' 'Product_67'
#  'Product_68' 'Product_69' 'Product_7' 'Product_70' 'Product_71'
#  'Product_72' 'Product_73' 'Product_74' 'Product_75' 'Product_76'
#  'Product_77' 'Product_78' 'Product_79' 'Product_8' 'Product_80'
#  'Product_81' 'Product_82' 'Product_83' 'Product_84' 'Product_85'
#  'Product_86' 'Product_87' 'Product_88' 'Product_89' 'Product_9'
#  'Product_90' 'Product_91' 'Product_92' 'Product_93' 'Product_94'
#  'Product_95' 'Product_96' 'Product_97' 'Product_98' 'Product_99']
#
# -----purchase_prices-----:----Size----
# ['Large' 'Medium' 'Small']
#
# -----purchase_prices-----:----Classification----
# ['A' 'B' 'C']
#
# -----purchase_prices-----:----VendorNumber----
# ['V001' 'V002' 'V003' 'V004' 'V005' 'V006' 'V007' 'V008' 'V009' 'V010'
#  'V011' 'V012' 'V013' 'V014' 'V015' 'V016' 'V017' 'V018' 'V019' 'V020'
#  'V021' 'V022' 'V023' 'V024' 'V025' 'V026' 'V027' 'V028' 'V029' 'V030'
#  'V031' 'V032' 'V033' 'V034' 'V035' 'V036' 'V037' 'V038' 'V039' 'V040']
#
# -----purchase_prices-----:----VendorName----
# ['Acevedo, Johnson and Higgins' 'Banks-Montgomery'
#  'Bartlett, Coleman and Gray' 'Carroll, Price and Perez' 'Cordova LLC'
#  'Cortez Inc' 'Fuentes, Richards and Johnson' 'Gaines-Mckinney'
#  'Grant-Adams' 'Griffin-York' 'Harrington-Gray' 'Harris PLC'
#  'Hicks-Jackson' 'Hill LLC' 'Jackson Group' 'Johnson, Carey and Nichols'
#  'Kane and Sons' 'Keith-Sanchez' 'Lara Group' 'Long-Roberts'
#  'Martinez, Jones and Osborne' 'Mccarthy, Davis and Mccormick'
#  'Mcdaniel-Le' 'Mcdonald Ltd' 'Mclaughlin-Smith' 'Norris-Ortega'
#  'Parker-Rogers' 'Pratt, Parrish and Reilly' 'Reese, Baker and Sutton'
#  'Rodriguez-Nguyen' 'Schroeder, Payne and Hooper' 'Shannon Ltd'
#  'Shaw, Brown and Ferguson' 'Thompson-Edwards' 'Valdez Group'
#  'Wade, Williams and Nichols' 'Watts Group' 'Willis and Sons'
#  'Wolfe-Murillo']
#
# -----sales-----:----Store----
# ['Store_1' 'Store_10' 'Store_11' 'Store_12' 'Store_13' 'Store_14'
#  'Store_15' 'Store_16' 'Store_17' 'Store_18' 'Store_2' 'Store_3' 'Store_4'
#  'Store_5' 'Store_6' 'Store_7' 'Store_8' 'Store_9']
#
# -----sales-----:----Brand----
# ['BRD-1' 'BRD-10' 'BRD-11' 'BRD-12' 'BRD-13' 'BRD-14' 'BRD-15' 'BRD-16'
#  'BRD-17' 'BRD-18' 'BRD-19' 'BRD-2' 'BRD-20' 'BRD-21' 'BRD-22' 'BRD-23'
#  'BRD-24' 'BRD-25' 'BRD-3' 'BRD-4' 'BRD-5' 'BRD-6' 'BRD-7' 'BRD-8' 'BRD-9'
#  'Brand 1' 'Brand 10' 'Brand 11' 'Brand 12' 'Brand 13' 'Brand 14'
#  'Brand 15' 'Brand 16' 'Brand 17' 'Brand 18' 'Brand 19' 'Brand 2'
#  'Brand 20' 'Brand 21' 'Brand 22' 'Brand 23' 'Brand 24' 'Brand 25'
#  'Brand 3' 'Brand 4' 'Brand 5' 'Brand 6' 'Brand 7' 'Brand 8' 'Brand 9'
#  'Brand_1' 'Brand_10' 'Brand_11' 'Brand_12' 'Brand_13' 'Brand_14'
#  'Brand_15' 'Brand_16' 'Brand_17' 'Brand_18' 'Brand_19' 'Brand_2'
#  'Brand_20' 'Brand_21' 'Brand_22' 'Brand_23' 'Brand_24' 'Brand_25'
#  'Brand_3' 'Brand_4' 'Brand_5' 'Brand_6' 'Brand_7' 'Brand_8' 'Brand_9'
#  'brand_1' 'brand_10' 'brand_11' 'brand_12' 'brand_13' 'brand_14'
#  'brand_15' 'brand_16' 'brand_17' 'brand_18' 'brand_19' 'brand_2'
#  'brand_20' 'brand_21' 'brand_22' 'brand_23' 'brand_24' 'brand_25'
#  'brand_3' 'brand_4' 'brand_5' 'brand_6' 'brand_7' 'brand_8' 'brand_9']
#
# -----sales-----:----Description----
# ['Product_1' 'Product_10' 'Product_100' 'Product_101' 'Product_102'
#  'Product_103' 'Product_104' 'Product_105' 'Product_106' 'Product_107'
#  'Product_108' 'Product_109' 'Product_11' 'Product_110' 'Product_111'
#  'Product_112' 'Product_113' 'Product_114' 'Product_115' 'Product_116'
#  'Product_117' 'Product_118' 'Product_119' 'Product_12' 'Product_120'
#  'Product_121' 'Product_122' 'Product_123' 'Product_124' 'Product_125'
#  'Product_126' 'Product_127' 'Product_128' 'Product_129' 'Product_13'
#  'Product_130' 'Product_131' 'Product_132' 'Product_133' 'Product_134'
#  'Product_135' 'Product_136' 'Product_137' 'Product_138' 'Product_139'
#  'Product_14' 'Product_140' 'Product_141' 'Product_142' 'Product_143'
#  'Product_144' 'Product_145' 'Product_146' 'Product_147' 'Product_148'
#  'Product_149' 'Product_15' 'Product_150' 'Product_151' 'Product_152'
#  'Product_153' 'Product_154' 'Product_155' 'Product_156' 'Product_157'
#  'Product_158' 'Product_159' 'Product_16' 'Product_160' 'Product_161'
#  'Product_162' 'Product_163' 'Product_164' 'Product_165' 'Product_166'
#  'Product_167' 'Product_168' 'Product_169' 'Product_17' 'Product_170'
#  'Product_171' 'Product_172' 'Product_173' 'Product_174' 'Product_175'
#  'Product_176' 'Product_177' 'Product_178' 'Product_179' 'Product_18'
#  'Product_180' 'Product_19' 'Product_2' 'Product_20' 'Product_21'
#  'Product_22' 'Product_23' 'Product_24' 'Product_25' 'Product_26'
#  'Product_27' 'Product_28' 'Product_29' 'Product_3' 'Product_30'
#  'Product_31' 'Product_32' 'Product_33' 'Product_34' 'Product_35'
#  'Product_36' 'Product_37' 'Product_38' 'Product_39' 'Product_4'
#  'Product_40' 'Product_41' 'Product_42' 'Product_43' 'Product_44'
#  'Product_45' 'Product_46' 'Product_47' 'Product_48' 'Product_49'
#  'Product_5' 'Product_50' 'Product_51' 'Product_52' 'Product_53'
#  'Product_54' 'Product_55' 'Product_56' 'Product_57' 'Product_58'
#  'Product_59' 'Product_6' 'Product_60' 'Product_61' 'Product_62'
#  'Product_63' 'Product_64' 'Product_65' 'Product_66' 'Product_67'
#  'Product_68' 'Product_69' 'Product_7' 'Product_70' 'Product_71'
#  'Product_72' 'Product_73' 'Product_74' 'Product_75' 'Product_76'
#  'Product_77' 'Product_78' 'Product_79' 'Product_8' 'Product_80'
#  'Product_81' 'Product_82' 'Product_83' 'Product_84' 'Product_85'
#  'Product_86' 'Product_87' 'Product_88' 'Product_89' 'Product_9'
#  'Product_90' 'Product_91' 'Product_92' 'Product_93' 'Product_94'
#  'Product_95' 'Product_96' 'Product_97' 'Product_98' 'Product_99']
#
# -----sales-----:----Size----
# ['Large' 'Medium' 'Small']
#
# -----sales-----:----SalesDate----
# ['01/01/2024' '01/01/24' '01/02/2024' ... 'Sep 28, 2024' 'Sep 29, 2024'
#  'Sep 30, 2024']
#
# -----sales-----:----Classification----
# ['A' 'B' 'C']
#
# -----sales-----:----VendorNo----
# ['V001' 'V002' 'V003' 'V004' 'V005' 'V006' 'V007' 'V008' 'V009' 'V010'
#  'V011' 'V012' 'V013' 'V014' 'V015' 'V016' 'V017' 'V018' 'V019' 'V020'
#  'V021' 'V022' 'V023' 'V024' 'V025' 'V026' 'V027' 'V028' 'V029' 'V030'
#  'V031' 'V032' 'V033' 'V034' 'V035' 'V036' 'V037' 'V038' 'V039' 'V040']
#
# -----sales-----:----VendorName----
# ['ACEVEDO, JOHNSON AND HIGGINS' 'BANKS-MONTGOMERY'
#  'Bartlett, Coleman and Gray Ltd' 'Carroll, Price and Perez' 'Cortez Inc'
#  'FUENTES, RICHARDS AND JOHNSON' 'GRIFFIN-YORK' 'Gaines-Mckinney Ltd'
#  'Grant-Adams Ltd' 'HILL LLC' 'Harrington-Gray' 'Harris_PLC' 'Hill LLC'
#  'Jackson Group' 'Johnson, Carey and Nichols' 'Kane_and_Sons'
#  'Keith-Sanchez' 'Lara_Group' 'Long-Roberts' 'MCDONALD LTD'
#  'Martinez, Jones and Osborne' 'Mccarthy,_Davis_and_Mccormick'
#  'Mcdaniel-Le' 'Mclaughlin-Smith' 'Norris-Ortega'
#  'Pratt, Parrish and Reilly' 'Reese, Baker and Sutton Ltd'
#  'Rodriguez-Nguyen Ltd' 'Schroeder, Payne and Hooper' 'Shannon Ltd'
#  'Shaw, Brown and Ferguson' 'Thompson-Edwards' 'Valdez Group'
#  'WADE, WILLIAMS AND NICHOLS' 'WATTS GROUP' 'Willis and Sons Ltd'
#  'Wolfe-Murillo Ltd' 'acevedo, johnson and higgins' 'banks-montgomery'
#  'bartlett, coleman and gray ltd' 'carroll, price and perez' 'cordova llc'
#  'cortez inc' 'fuentes, richards and johnson' 'gaines-mckinney ltd'
#  'grant-adams ltd' 'griffin-york' 'harrington-gray' 'harris_plc'
#  'hicks-jackson' 'hill llc' 'jackson group' 'johnson, carey and nichols'
#  'kane_and_sons' 'keith-sanchez' 'lara_group' 'long-roberts'
#  'martinez, jones and osborne' 'mccarthy,_davis_and_mccormick'
#  'mcdaniel-le' 'mcdonald ltd' 'mclaughlin-smith' 'norris-ortega'
#  'parker-rogers' 'pratt, parrish and reilly' 'reese, baker and sutton ltd'
#  'rodriguez-nguyen ltd' 'schroeder, payne and hooper' 'shannon ltd'
#  'shaw, brown and ferguson' 'thompson-edwards' 'valdez group'
#  'wade, williams and nichols' 'watts group' 'willis and sons ltd'
#  'wolfe-murillo ltd']
#
# -----vendor_invoice-----:----VendorNumber----
# ['None' 'V001' 'V002' 'V003' 'V004' 'V005' 'V006' 'V007' 'V008' 'V009'
#  'V010' 'V011' 'V012' 'V013' 'V014' 'V015' 'V016' 'V017' 'V018' 'V019'
#  'V020' 'V021' 'V022' 'V023' 'V024' 'V025' 'V026' 'V027' 'V028' 'V029'
#  'V030' 'V031' 'V032' 'V033' 'V034' 'V035' 'V036' 'V037' 'V038' 'V039'
#  'V040']
#
# -----vendor_invoice-----:----VendorName----
# ['ACEVEDO, JOHNSON AND HIGGINS' 'BANKS-MONTGOMERY'
#  'Bartlett, Coleman and Gray Ltd' 'Carroll, Price and Perez' 'Cortez Inc'
#  'FUENTES, RICHARDS AND JOHNSON' 'GRIFFIN-YORK' 'Gaines-Mckinney Ltd'
#  'Grant-Adams Ltd' 'HILL LLC' 'Harrington-Gray' 'Harris_PLC' 'Hill LLC'
#  'Jackson Group' 'Johnson, Carey and Nichols' 'Kane_and_Sons'
#  'Keith-Sanchez' 'Lara_Group' 'Long-Roberts' 'MCDONALD LTD'
#  'Martinez, Jones and Osborne' 'Mccarthy,_Davis_and_Mccormick'
#  'Mcdaniel-Le' 'Mclaughlin-Smith' 'Norris-Ortega'
#  'Pratt, Parrish and Reilly' 'Reese, Baker and Sutton Ltd'
#  'Rodriguez-Nguyen Ltd' 'Schroeder, Payne and Hooper' 'Shannon Ltd'
#  'Shaw, Brown and Ferguson' 'Thompson-Edwards' 'Valdez Group'
#  'WADE, WILLIAMS AND NICHOLS' 'WATTS GROUP' 'Willis and Sons Ltd'
#  'Wolfe-Murillo Ltd' 'cordova llc' 'hicks-jackson' 'parker-rogers']
#
# -----vendor_invoice-----:----InvoiceDate----
# ['02/03/24' '02/05/24' '02/07/2024' '02/09/2024' '02/21/2024' '03/04/2024'
#  '04/09/24' '05/26/2024' '06/01/2024' '07/08/24' '07/16/2024' '07/19/2024'
#  '10/03/24' '12/20/2024' '17/11/24' '2024-03-23' '2024-05-30' '2024-06-19'
#  '2024-07-13' '2024-07-19' '2024-09-02' '2024-09-25' '2024-11-22'
#  '23/04/24' '25/10/24' '28/12/24' '30/04/24' '30/12/24' 'Apr 08, 2024'
#  'Apr 26, 2024' 'Aug 13, 2024' 'Feb 02, 2024' 'Jan 01, 2024'
#  'Jul 26, 2024' 'Jun 14, 2024' 'Mar 01, 2024' 'Mar 06, 2024'
#  'Mar 28, 2024' 'Nov 30, 2024' 'Sep 23, 2024']
#
# -----vendor_invoice-----:----PODate----
# ['02/03/2024' '03/21/2024' '05/21/2024' '07/26/2024' '08/11/24'
#  '09/21/2024' '10/04/2024' '11/10/2024' '11/17/2024' '11/20/2024'
#  '12/20/2024' '15/02/24' '2024-03-28' '2024-04-08' '2024-05-08'
#  '2024-10-12' '22/08/24' '23/09/24' '24/08/24' '25/09/24' '26/02/24'
#  '28/04/24' '28/08/24' 'Apr 15, 2024' 'Dec 23, 2024' 'Feb 21, 2024'
#  'Jan 30, 2024' 'Jul 01, 2024' 'Jul 06, 2024' 'Jul 11, 2024'
#  'Jul 16, 2024' 'Jun 18, 2024' 'Mar 17, 2024' 'Mar 26, 2024'
#  'Nov 22, 2024' 'Oct 15, 2024' 'Oct 31, 2024']
#
# -----vendor_invoice-----:----PayDate----
# ['01/22/2024' '02/03/24' '04/02/24' '07/14/2024' '07/22/2024' '07/29/2024'
#  '08/21/2024' '09/04/24' '09/07/2024' '09/09/2024' '10/12/24' '10/17/2024'
#  '11/15/2024' '12/04/2024' '12/19/2024' '15/03/24' '16/12/24' '17/06/24'
#  '17/09/24' '2024-01-10' '2024-02-04' '2024-02-18' '2024-02-24'
#  '2024-03-11' '2024-04-01' '2024-04-15' '2024-05-20' '2024-07-02'
#  '2024-08-19' '2024-10-17' '2024-10-28' '2024-11-07' '25/04/24' '28/06/24'
#  'Aug 10, 2024' 'Dec 09, 2024' 'Feb 04, 2024' 'Jan 03, 2024'
#  'Jan 08, 2024' 'Jul 02, 2024']
#
# -----vendor_invoice-----:----PONumber----
# ['PO-0353' 'PO-0551' 'PO-0734' 'PO-1302' 'PO-1476' 'PO-1759' 'PO-1810'
#  'PO-2203' 'PO-2331' 'PO-3115' 'PO-3912' 'PO-4024' 'PO-4122' 'PO-4242'
#  'PO-4554' 'PO-4583' 'PO-5303' 'PO-5624' 'PO-5662' 'PO-5717' 'PO-5749'
#  'PO-5765' 'PO-5843' 'PO-5865' 'PO-5958' 'PO-6668' 'PO-6824' 'PO-6846'
#  'PO-7385' 'PO-7614' 'PO-7801' 'PO-7829' 'PO-8174' 'PO-8574' 'PO-8697'
#  'PO-9050' 'PO-9159' 'PO-9178' 'PO-9317' 'PO-9711']
#
# -----vendor_invoice-----:----Approval----
# ['Approved' 'Pending' 'Rejected']
#
# -----begin_inventory-----:----City----
# ['Adambury' 'Crossshire' 'East Jessicastad' 'Lake Davidchester'
#  'Lake Ryanmouth' 'Lisaside' 'Loriland' 'New Dawn' 'Port Brett'
#  'Port Joshua' 'Port Shawn' 'Shanemouth' 'South Danielle' 'South Peter'
#  'South Victorberg' 'Stevenmouth' 'Toddfurt' 'West Amber']
#
# -----begin_inventory-----:----Brand----
# ['Brand_1' 'Brand_10' 'Brand_11' 'Brand_12' 'Brand_13' 'Brand_14'
#  'Brand_15' 'Brand_16' 'Brand_17' 'Brand_18' 'Brand_19' 'Brand_2'
#  'Brand_20' 'Brand_21' 'Brand_22' 'Brand_23' 'Brand_24' 'Brand_25'
#  'Brand_3' 'Brand_4' 'Brand_5' 'Brand_6' 'Brand_7' 'Brand_8' 'Brand_9'
#  'brand_1' 'brand_10' 'brand_11' 'brand_12' 'brand_13' 'brand_14'
#  'brand_15' 'brand_16' 'brand_18' 'brand_19' 'brand_2' 'brand_21'
#  'brand_22' 'brand_23' 'brand_24' 'brand_25' 'brand_3' 'brand_4' 'brand_5'
#  'brand_6' 'brand_7' 'brand_8' 'brand_9']
#
# -----end_inventory-----:----City----
# ['Adambury' 'Crossshire' 'East Jessicastad' 'Lake Davidchester'
#  'Lake Ryanmouth' 'Lisaside' 'Loriland' 'New Dawn' 'Port Brett'
#  'Port Joshua' 'Port Shawn' 'Shanemouth' 'South Danielle' 'South Peter'
#  'South Victorberg' 'Stevenmouth' 'Toddfurt' 'West Amber']
#
# -----end_inventory-----:----Brand----
# ['Brand_1' 'Brand_10' 'Brand_11' 'Brand_12' 'Brand_13' 'Brand_14'
#  'Brand_15' 'Brand_16' 'Brand_17' 'Brand_18' 'Brand_19' 'Brand_2'
#  'Brand_20' 'Brand_21' 'Brand_22' 'Brand_23' 'Brand_24' 'Brand_25'
#  'Brand_3' 'Brand_4' 'Brand_5' 'Brand_6' 'Brand_7' 'Brand_8' 'Brand_9']
#
# -----purchases-----:----Brand----
# ['BRD-1' 'BRD-10' 'BRD-11' 'BRD-12' 'BRD-13' 'BRD-14' 'BRD-15' 'BRD-16'
#  'BRD-17' 'BRD-18' 'BRD-19' 'BRD-2' 'BRD-20' 'BRD-21' 'BRD-22' 'BRD-23'
#  'BRD-24' 'BRD-25' 'BRD-3' 'BRD-4' 'BRD-5' 'BRD-6' 'BRD-7' 'BRD-8' 'BRD-9'
#  'Brand 1' 'Brand 10' 'Brand 11' 'Brand 12' 'Brand 13' 'Brand 14'
#  'Brand 15' 'Brand 16' 'Brand 17' 'Brand 18' 'Brand 19' 'Brand 2'
#  'Brand 20' 'Brand 21' 'Brand 22' 'Brand 23' 'Brand 24' 'Brand 25'
#  'Brand 3' 'Brand 4' 'Brand 5' 'Brand 6' 'Brand 7' 'Brand 8' 'Brand 9'
#  'Brand_1' 'Brand_10' 'Brand_11' 'Brand_12' 'Brand_13' 'Brand_14'
#  'Brand_15' 'Brand_16' 'Brand_17' 'Brand_18' 'Brand_19' 'Brand_2'
#  'Brand_20' 'Brand_21' 'Brand_22' 'Brand_23' 'Brand_24' 'Brand_25'
#  'Brand_3' 'Brand_4' 'Brand_5' 'Brand_6' 'Brand_7' 'Brand_8' 'Brand_9'
#  'brand_1' 'brand_10' 'brand_11' 'brand_12' 'brand_13' 'brand_14'
#  'brand_15' 'brand_16' 'brand_17' 'brand_18' 'brand_19' 'brand_2'
#  'brand_20' 'brand_21' 'brand_22' 'brand_23' 'brand_24' 'brand_25'
#  'brand_3' 'brand_4' 'brand_5' 'brand_6' 'brand_7' 'brand_8' 'brand_9']
#
# -----purchases-----:----VendorName----
# ['ACEVEDO, JOHNSON AND HIGGINS' 'BANKS-MONTGOMERY'
#  'BARTLETT, COLEMAN AND GRAY LTD' 'Bartlett, Coleman and Gray Ltd'
#  'CARROLL, PRICE AND PEREZ' 'CORDOVA LLC' 'CORTEZ INC'
#  'Carroll, Price and Perez' 'Cortez Inc' 'FUENTES, RICHARDS AND JOHNSON'
#  'GAINES-MCKINNEY LTD' 'GRANT-ADAMS LTD' 'GRIFFIN-YORK'
#  'Gaines-Mckinney Ltd' 'Grant-Adams Ltd' 'HARRINGTON-GRAY' 'HARRIS_PLC'
#  'HICKS-JACKSON' 'HILL LLC' 'Harrington-Gray' 'Harris_PLC' 'Hill LLC'
#  'JACKSON GROUP' 'JOHNSON, CAREY AND NICHOLS' 'Jackson Group'
#  'Johnson, Carey and Nichols' 'KANE_AND_SONS' 'KEITH-SANCHEZ'
#  'Kane_and_Sons' 'Keith-Sanchez' 'LARA_GROUP' 'LONG-ROBERTS' 'Lara_Group'
#  'Long-Roberts' 'MARTINEZ, JONES AND OSBORNE'
#  'MCCARTHY,_DAVIS_AND_MCCORMICK' 'MCDANIEL-LE' 'MCDONALD LTD'
#  'MCLAUGHLIN-SMITH' 'Martinez, Jones and Osborne'
#  'Mccarthy,_Davis_and_Mccormick' 'Mcdaniel-Le' 'Mclaughlin-Smith'
#  'NORRIS-ORTEGA' 'Norris-Ortega' 'PARKER-ROGERS'
#  'PRATT, PARRISH AND REILLY' 'Pratt, Parrish and Reilly'
#  'REESE, BAKER AND SUTTON LTD' 'RODRIGUEZ-NGUYEN LTD'
#  'Reese, Baker and Sutton Ltd' 'Rodriguez-Nguyen Ltd'
#  'SCHROEDER, PAYNE AND HOOPER' 'SHANNON LTD' 'SHAW, BROWN AND FERGUSON'
#  'Schroeder, Payne and Hooper' 'Shannon Ltd' 'Shaw, Brown and Ferguson'
#  'THOMPSON-EDWARDS' 'Thompson-Edwards' 'VALDEZ GROUP' 'Valdez Group'
#  'WADE, WILLIAMS AND NICHOLS' 'WATTS GROUP' 'WILLIS AND SONS LTD'
#  'WOLFE-MURILLO LTD' 'Willis and Sons Ltd' 'Wolfe-Murillo Ltd'
#  'cordova llc' 'hicks-jackson' 'parker-rogers']
#
# -----purchase_prices-----:----Brand----
# ['Brand_1' 'Brand_10' 'Brand_11' 'Brand_12' 'Brand_13' 'Brand_14'
#  'Brand_15' 'Brand_16' 'Brand_17' 'Brand_18' 'Brand_19' 'Brand_2'
#  'Brand_20' 'Brand_21' 'Brand_22' 'Brand_23' 'Brand_24' 'Brand_25'
#  'Brand_3' 'Brand_4' 'Brand_5' 'Brand_6' 'Brand_7' 'Brand_8' 'Brand_9'
#  'brand_1' 'brand_10' 'brand_11' 'brand_13' 'brand_15' 'brand_16'
#  'brand_17' 'brand_18' 'brand_19' 'brand_2' 'brand_20' 'brand_21'
#  'brand_23' 'brand_24' 'brand_25' 'brand_3' 'brand_4' 'brand_5' 'brand_6'
#  'brand_7' 'brand_9']
#
# -----purchase_prices-----:----VendorName----
# ['Acevedo, Johnson and Higgins' 'Banks-Montgomery'
#  'Bartlett, Coleman and Gray' 'Carroll, Price and Perez' 'Cordova LLC'
#  'Cortez Inc' 'Fuentes, Richards and Johnson' 'Gaines-Mckinney'
#  'Grant-Adams' 'Griffin-York' 'Harrington-Gray' 'Harris PLC'
#  'Hicks-Jackson' 'Hill LLC' 'Jackson Group' 'Johnson, Carey and Nichols'
#  'Kane and Sons' 'Keith-Sanchez' 'Lara Group' 'Long-Roberts'
#  'Martinez, Jones and Osborne' 'Mccarthy, Davis and Mccormick'
#  'Mcdaniel-Le' 'Mcdonald Ltd' 'Mclaughlin-Smith' 'Norris-Ortega'
#  'Parker-Rogers' 'Pratt, Parrish and Reilly' 'Reese, Baker and Sutton'
#  'Rodriguez-Nguyen' 'Schroeder, Payne and Hooper' 'Shannon Ltd'
#  'Shaw, Brown and Ferguson' 'Thompson-Edwards' 'Valdez Group'
#  'Wade, Williams and Nichols' 'Watts Group' 'Willis and Sons'
#  'Wolfe-Murillo']
#
# -----sales-----:----Brand----
# ['BRD-1' 'BRD-10' 'BRD-11' 'BRD-12' 'BRD-13' 'BRD-14' 'BRD-15' 'BRD-16'
#  'BRD-17' 'BRD-18' 'BRD-19' 'BRD-2' 'BRD-20' 'BRD-21' 'BRD-22' 'BRD-23'
#  'BRD-24' 'BRD-25' 'BRD-3' 'BRD-4' 'BRD-5' 'BRD-6' 'BRD-7' 'BRD-8' 'BRD-9'
#  'Brand 1' 'Brand 10' 'Brand 11' 'Brand 12' 'Brand 13' 'Brand 14'
#  'Brand 15' 'Brand 16' 'Brand 17' 'Brand 18' 'Brand 19' 'Brand 2'
#  'Brand 20' 'Brand 21' 'Brand 22' 'Brand 23' 'Brand 24' 'Brand 25'
#  'Brand 3' 'Brand 4' 'Brand 5' 'Brand 6' 'Brand 7' 'Brand 8' 'Brand 9'
#  'Brand_1' 'Brand_10' 'Brand_11' 'Brand_12' 'Brand_13' 'Brand_14'
#  'Brand_15' 'Brand_16' 'Brand_17' 'Brand_18' 'Brand_19' 'Brand_2'
#  'Brand_20' 'Brand_21' 'Brand_22' 'Brand_23' 'Brand_24' 'Brand_25'
#  'Brand_3' 'Brand_4' 'Brand_5' 'Brand_6' 'Brand_7' 'Brand_8' 'Brand_9'
#  'brand_1' 'brand_10' 'brand_11' 'brand_12' 'brand_13' 'brand_14'
#  'brand_15' 'brand_16' 'brand_17' 'brand_18' 'brand_19' 'brand_2'
#  'brand_20' 'brand_21' 'brand_22' 'brand_23' 'brand_24' 'brand_25'
#  'brand_3' 'brand_4' 'brand_5' 'brand_6' 'brand_7' 'brand_8' 'brand_9']
#
# -----sales-----:----VendorName----
# ['ACEVEDO, JOHNSON AND HIGGINS' 'BANKS-MONTGOMERY'
#  'Bartlett, Coleman and Gray Ltd' 'Carroll, Price and Perez' 'Cortez Inc'
#  'FUENTES, RICHARDS AND JOHNSON' 'GRIFFIN-YORK' 'Gaines-Mckinney Ltd'
#  'Grant-Adams Ltd' 'HILL LLC' 'Harrington-Gray' 'Harris_PLC' 'Hill LLC'
#  'Jackson Group' 'Johnson, Carey and Nichols' 'Kane_and_Sons'
#  'Keith-Sanchez' 'Lara_Group' 'Long-Roberts' 'MCDONALD LTD'
#  'Martinez, Jones and Osborne' 'Mccarthy,_Davis_and_Mccormick'
#  'Mcdaniel-Le' 'Mclaughlin-Smith' 'Norris-Ortega'
#  'Pratt, Parrish and Reilly' 'Reese, Baker and Sutton Ltd'
#  'Rodriguez-Nguyen Ltd' 'Schroeder, Payne and Hooper' 'Shannon Ltd'
#  'Shaw, Brown and Ferguson' 'Thompson-Edwards' 'Valdez Group'
#  'WADE, WILLIAMS AND NICHOLS' 'WATTS GROUP' 'Willis and Sons Ltd'
#  'Wolfe-Murillo Ltd' 'acevedo, johnson and higgins' 'banks-montgomery'
#  'bartlett, coleman and gray ltd' 'carroll, price and perez' 'cordova llc'
#  'cortez inc' 'fuentes, richards and johnson' 'gaines-mckinney ltd'
#  'grant-adams ltd' 'griffin-york' 'harrington-gray' 'harris_plc'
#  'hicks-jackson' 'hill llc' 'jackson group' 'johnson, carey and nichols'
#  'kane_and_sons' 'keith-sanchez' 'lara_group' 'long-roberts'
#  'martinez, jones and osborne' 'mccarthy,_davis_and_mccormick'
#  'mcdaniel-le' 'mcdonald ltd' 'mclaughlin-smith' 'norris-ortega'
#  'parker-rogers' 'pratt, parrish and reilly' 'reese, baker and sutton ltd'
#  'rodriguez-nguyen ltd' 'schroeder, payne and hooper' 'shannon ltd'
#  'shaw, brown and ferguson' 'thompson-edwards' 'valdez group'
#  'wade, williams and nichols' 'watts group' 'willis and sons ltd'
#  'wolfe-murillo ltd']
#
# -----vendor_invoice-----:----VendorName----
# ['ACEVEDO, JOHNSON AND HIGGINS' 'BANKS-MONTGOMERY'
#  'Bartlett, Coleman and Gray Ltd' 'Carroll, Price and Perez' 'Cortez Inc'
#  'FUENTES, RICHARDS AND JOHNSON' 'GRIFFIN-YORK' 'Gaines-Mckinney Ltd'
#  'Grant-Adams Ltd' 'HILL LLC' 'Harrington-Gray' 'Harris_PLC' 'Hill LLC'
#  'Jackson Group' 'Johnson, Carey and Nichols' 'Kane_and_Sons'
#  'Keith-Sanchez' 'Lara_Group' 'Long-Roberts' 'MCDONALD LTD'
#  'Martinez, Jones and Osborne' 'Mccarthy,_Davis_and_Mccormick'
#  'Mcdaniel-Le' 'Mclaughlin-Smith' 'Norris-Ortega'
#  'Pratt, Parrish and Reilly' 'Reese, Baker and Sutton Ltd'
#  'Rodriguez-Nguyen Ltd' 'Schroeder, Payne and Hooper' 'Shannon Ltd'
#  'Shaw, Brown and Ferguson' 'Thompson-Edwards' 'Valdez Group'
#  'WADE, WILLIAMS AND NICHOLS' 'WATTS GROUP' 'Willis and Sons Ltd'
#  'Wolfe-Murillo Ltd' 'cordova llc' 'hicks-jackson' 'parker-rogers']

# %%
## DEFINING A FUNCTION TO RESOLVE ALL INCONSISTENCIES AT ONCE

def clean_brand(x):
    if pd.isna(x): 
        return None
    x = x.lower()                     
    x = x.replace('-','_')
    x = x.replace('BRD-','Brand_')
    x = x.replace('brd','Brand')
    x = x.replace('Brand ', 'Brand_') # converts Brand 1 → Brand_1
    x = x.replace('-', '_')           # handles any leftover dashes   
    x = x.title()                     # makes “brand_1” → “Brand_1”
    return x


## APPLYING THE FUNCTIONS TO THE REQUIRED TABLES
for name in ['begin_inventory', 'end_inventory', 'purchases', 'purchase_prices', 'sales']:
    dfs[name]['Brand_clean'] = dfs[name]['Brand'].apply(clean_brand)

#----------------------------------------------------------------

# %%
## DEFINING A FUNCTION TO RESOLVE ALL INCONSISTENCIES AT ONCE

def clean_vendor_name(x):
    if pd.isna(x):
        return None
    x = x.lower()
    x = x.replace('-', ' ').replace('_', ' ').replace('.', ' ')
    x = x.replace('ltd ','Ltd')
    x = x.replace('ltd','Ltd')
    x = x.replace('limited ','Ltd')
    x = x.replace('Inc ','Inc')
    x = x.replace('llc','LLC')
    x = x.title()
    return x

## APPLYING THE FUNCTIONS TO THE REQUIRED TABLES
for name in ['purchases', 'purchase_prices', 'sales', 'vendor_invoice']:
    dfs[name]['VendorName_clean'] = dfs[name]['VendorName'].apply(clean_vendor_name)

#----------------------------------------------------------------

# %%
## CREATING A MASTER LIST OF ALL VALUES FOR FINAL REVIEW

master_vendor_names = pd.concat([
    dfs['purchases']['VendorName_clean'],
    dfs['purchase_prices']['VendorName_clean'],
    dfs['sales']['VendorName_clean'],
    dfs['vendor_invoice']['VendorName_clean']]).dropna().unique()

pd.Series(master_vendor_names).sort_values()

## MANUALLY MAPPING THE CORRECT NAMES

vendor_names_map = {
    'Estradamendoza': 'Estradamendoza Ltd', 
    'Fitzgeraldllc':'Fitzgerald Llc',
    'Garza Llc':'Garza Llc Ltd',
    'Moranbray': 'Moranbray Ltd',
    'Nguyen Group': 'Nguyen Group Ltd', 
    'Nguyenthomas': 'Nguyenthomas Ltd', 
    'Snyder, Scott And Haas': 'Snyder, Scott And Haas Ltd', 
    'Thompson Group': 'Thompson Group', 
    'Williams,Hickmanandnichols':'Williams, Hickman And Nichols'}

for name in ['purchases', 'purchase_prices', 'sales', 'vendor_invoice']:
    dfs[name]['VendorName_clean'] = dfs[name]['VendorName_clean'].replace(vendor_names_map)

# %%
for name, df in dfs.items():  
    print('-'*50, name, '-'*50)
    display(df)
# Out:
# -------------------------------------------------- begin_inventory --------------------------------------------------
#       InventoryId     Store              City     Brand  Description    Size  \
# 0          100000   Store_8          Toddfurt  Brand_21   Product_71  Medium
# 1          100001   Store_9        Port Shawn   Brand_3   Product_87   Small
# 2          100002   Store_9          Lisaside   Brand_2  Product_112   Small
# 3          100003   Store_5    South Danielle  Brand_12   Product_31   Small
# 4          100004   Store_8          Toddfurt  Brand_24  Product_179   Large
# ...           ...       ...               ...       ...          ...     ...
# 7995       107995   Store_9  East Jessicastad   Brand_4  Product_117  Medium
# 7996       107996  Store_13    South Danielle   Brand_6   Product_58   Small
# 7997       107997  Store_18       South Peter  Brand_16  Product_155  Medium
# 7998       107998  Store_14       South Peter  Brand_19   Product_64  Medium
# 7999       107999   Store_5        Shanemouth  Brand_22   Product_27   Large
#
#       onHand   Price     startDate startDate_clean Brand_clean
# 0        343   82.44  Jun 24, 2024      2024-06-24    Brand_21
# 1        241  157.82    2024-01-17      2024-01-17     Brand_3
# 2        544  251.95    05/09/2024      2024-09-05     Brand_2
# 3        323  156.20      24/08/24      2024-08-24    Brand_12
# 4         31  193.32    06/06/2024      2024-06-06    Brand_24
# ...      ...     ...           ...             ...         ...
# 7995     738  136.49      12/08/24      2024-08-12     Brand_4
# 7996      10  299.58  Aug 09, 2024      2024-08-09     Brand_6
# 7997     676   89.28  Nov 08, 2024      2024-11-08    Brand_16
# 7998     553  167.78  Apr 24, 2024      2024-04-24    Brand_19
# 7999       8  234.57      06/12/24      2024-12-06    Brand_22
#
# [8000 rows x 11 columns]
# -------------------------------------------------- end_inventory --------------------------------------------------
#       InventoryId     Store               City     Brand  Description    Size  \
# 0          200000   Store_4  Lake Davidchester  Brand_19  Product_124  Medium
# 1          200001  Store_13           New Dawn   Brand_6  Product_140   Large
# 2          200002   Store_9           Loriland  Brand_22   Product_67   Large
# 3          200003  Store_15     South Danielle  Brand_25   Product_52   Large
# 4          200004   Store_9         Shanemouth  Brand_17   Product_23   Small
# ...           ...       ...                ...       ...          ...     ...
# 7995       207995  Store_16     South Danielle   Brand_9    Product_8   Small
# 7996       207996  Store_17           New Dawn  Brand_23   Product_25   Small
# 7997       207997   Store_3           Toddfurt  Brand_14    Product_2   Large
# 7998       207998  Store_13        South Peter   Brand_3  Product_110   Small
# 7999       207999   Store_8     South Danielle  Brand_18  Product_103  Medium
#
#       onHand   Price       endDate endDate_clean Brand_clean
# 0        159  173.20  Aug 16, 2024    2024-08-16    Brand_19
# 1        588  232.66    10/11/2024    2024-11-10     Brand_6
# 2        556  113.63  Feb 23, 2024    2024-02-23    Brand_22
# 3        360  241.09  Jul 17, 2024    2024-07-17    Brand_25
# 4        642  285.39    2024-01-04    2024-01-04    Brand_17
# ...      ...     ...           ...           ...         ...
# 7995     458  135.46      15/06/24    2024-06-15     Brand_9
# 7996      10   98.20    2024-09-09    2024-09-09    Brand_23
# 7997     816  194.73    2024-01-27    2024-01-27    Brand_14
# 7998     316  327.70    09/01/2024    2024-01-09     Brand_3
# 7999     833  148.22    2024-09-30    2024-09-30    Brand_18
#
# [8000 rows x 11 columns]
# -------------------------------------------------- purchases --------------------------------------------------
#        InventoryId     Store     Brand  Description   Size VendorNumber  \
# 0           300000  Store_17   brand_6   Product_53  Large         V038
# 1           300001   Store_4   Brand 7  Product_136  Small         V009
# 2           300002  Store_12  Brand_18   Product_51  Small         V015
# 3           300003   Store_9  brand_19  Product_131  Large         V014
# 4           300004  Store_16   Brand_7  Product_159  Large         V009
# ...            ...       ...       ...          ...    ...          ...
# 32295       330791   Store_2  brand_24   Product_14  Large         V038
# 32296       306245   Store_2   brand_3  Product_127  Small         V004
# 32297       319000  Store_12  brand_21   Product_22  Small         V024
# 32298       307707   Store_2  brand_11   Product_66  Large         V002
# 32299       321122   Store_9    BRD-17   Product_10  Small         V012
#
#                         VendorName    PONumber        PODate ReceivingDate  \
# 0                      Shannon Ltd  PO-9557-bh    04/03/2024    12/13/2024
# 1                    Jackson Group  PO-4140-Bm    2024-06-09  Oct 14, 2024
# 2                Wolfe-Murillo Ltd  PO-1722-ls  May 14, 2024    05/29/2024
# 3         Carroll, Price and Perez  PO-8521-gH    2024-04-20    2024-03-08
# 4                    Jackson Group  PO-8073-SP    07/25/2024    2024-02-11
# ...                            ...         ...           ...           ...
# 32295                  Shannon Ltd  PO-8701-HQ      21/08/24    2024-04-24
# 32296                Keith-Sanchez  PO-6957-VD    06/15/2024  Aug 22, 2024
# 32297  Schroeder, Payne and Hooper  PO-8746-LF      07/12/24    2024-10-14
# 32298                 Long-Roberts  PO-4291-Kz  Jun 04, 2024  Aug 15, 2024
# 32299                     Hill LLC  PO-3447-FZ    11/11/2024    2024-01-17
#
#        ...       PayDate PurchasePrice  Quantity  Classification   Dollars  \
# 0      ...      17/07/24        174.17      74.0               A  12888.58
# 1      ...    2024-11-24        165.21      53.0               A   8756.13
# 2      ...    05/26/2024        166.58     168.0               A  27985.44
# 3      ...  Jul 23, 2024        180.35     148.0               C  26691.80
# 4      ...      18/01/24        191.35     420.0               B  80367.00
# ...    ...           ...           ...       ...             ...       ...
# 32295  ...    10/24/2024        161.61     420.0               A  67876.20
# 32296  ...    10/06/2024        166.11     283.0               C  47009.13
# 32297  ...    2024-07-25        151.07     258.0               A  38976.06
# 32298  ...    2024-10-28        166.04     251.0               A  41676.04
# 32299  ...    2024-03-20        162.82     331.0               C  53893.42
#
#        ReceivingDate_clean InvoiceDate_clean PayDate_clean Brand_clean  \
# 0               2024-12-13        2024-01-23    2024-07-17     Brand_6
# 1               2024-10-14        2024-08-27    2024-11-24     Brand 7
# 2               2024-05-29        2024-01-28    2024-05-26    Brand_18
# 3               2024-03-08        2024-07-14    2024-07-23    Brand_19
# 4               2024-02-11        2024-03-18    2024-01-18     Brand_7
# ...                    ...               ...           ...         ...
# 32295           2024-04-24        2024-01-09    2024-10-24    Brand_24
# 32296           2024-08-22        2024-06-03    2024-06-10     Brand_3
# 32297           2024-10-14        2024-09-15    2024-07-25    Brand_21
# 32298           2024-08-15        2024-10-16    2024-10-28    Brand_11
# 32299           2024-01-17        2024-09-25    2024-03-20    Brand_17
#
#                   VendorName_clean
# 0                      Shannon Ltd
# 1                    Jackson Group
# 2                Wolfe Murillo Ltd
# 3         Carroll, Price And Perez
# 4                    Jackson Group
# ...                            ...
# 32295                  Shannon Ltd
# 32296                Keith Sanchez
# 32297  Schroeder, Payne And Hooper
# 32298                 Long Roberts
# 32299                     Hill Llc
#
# [32300 rows x 21 columns]
# -------------------------------------------------- purchase_prices --------------------------------------------------
#           Brand  Description   Price    Size  Volume Classification  \
# 0       Brand_7  Product_143  111.24  Medium       6              A
# 1      Brand_20  Product_169  226.35   Large      12              C
# 2      Brand_15  Product_115  252.93   Small      12              C
# 3      Brand_11  Product_109  255.70   Small       6              B
# 4       Brand_8   Product_90  254.02  Medium      24              C
# ...         ...          ...     ...     ...     ...            ...
# 11995  Brand_25   Product_91  298.41   Small       6              A
# 11996  Brand_19  Product_132  117.69   Large      12              C
# 11997   Brand_3    Product_2  203.85   Small      24              B
# 11998   Brand_4  Product_115  159.13   Small      12              B
# 11999  Brand_11    Product_1  207.98  Medium       6              B
#
#        PurchasePrice VendorNumber                  VendorName Brand_clean  \
# 0             125.27         V018                Long-Roberts     Brand_7
# 1             223.92         V013               Jackson Group    Brand_20
# 2             174.18         V031                  Harris PLC    Brand_15
# 3             222.85         V003   Pratt, Parrish and Reilly    Brand_11
# 4             242.18         V030            Banks-Montgomery     Brand_8
# ...              ...          ...                         ...         ...
# 11995         130.93         V005               Parker-Rogers    Brand_25
# 11996         208.41         V027     Reese, Baker and Sutton    Brand_19
# 11997         105.83         V012             Gaines-Mckinney     Brand_3
# 11998         278.30         V010     Reese, Baker and Sutton     Brand_4
# 11999         119.01         V009  Wade, Williams and Nichols    Brand_11
#
#                  VendorName_clean
# 0                    Long Roberts
# 1                   Jackson Group
# 2                      Harris Plc
# 3       Pratt, Parrish And Reilly
# 4                Banks Montgomery
# ...                           ...
# 11995               Parker Rogers
# 11996     Reese, Baker And Sutton
# 11997             Gaines Mckinney
# 11998     Reese, Baker And Sutton
# 11999  Wade, Williams And Nichols
#
# [12000 rows x 11 columns]
# -------------------------------------------------- sales --------------------------------------------------
#        InventoryId     Store     Brand  Description    Size  SalesQuantity  \
# 0           400000  Store_11   brand_9   Product_94   Large          352.0
# 1           400001  Store_14  brand_12   Product_29   Small           58.0
# 2           400002   Store_3  Brand_21  Product_119  Medium           57.0
# 3           400003   Store_1  Brand 25  Product_163   Large          354.0
# 4           400004  Store_16     BRD-3   Product_18  Medium          334.0
# ...            ...       ...       ...          ...     ...            ...
# 95045       464255  Store_16  brand_14   Product_41   Large          296.0
# 95046       404341  Store_10     BRD-6   Product_40  Medium           93.0
# 95047       481145   Store_1     BRD-7   Product_65  Medium           80.0
# 95048       492573  Store_18  Brand 17   Product_34  Medium          168.0
# 95049       467887   Store_3    BRD-14   Product_70   Large          373.0
#
#        SalesPrice     SalesDate  Volume Classification VendorNo  \
# 0          211.36    06/09/2024    5292              C     V004
# 1          244.67    03/10/2024    8851              B     V017
# 2          200.76  Dec 15, 2024    7843              C     V031
# 3          228.12  Jan 11, 2024    1376              C     V026
# 4          221.32  May 29, 2024    7600              C     V005
# ...           ...           ...     ...            ...      ...
# 95045      194.11    08/28/2024    5035              A     V009
# 95046      219.55  Jul 27, 2024   10174              C     V012
# 95047      212.76      10/05/24    7168              B     V036
# 95048      185.08    06/13/2024    9745              C     V022
# 95049      229.64      24/10/24    2934              B     V007
#
#                           VendorName  SalesDollars  ExciseTax Brand_clean  \
# 0                      Keith-Sanchez      74398.72    3943.99     Brand_9
# 1                    Harrington-Gray      14190.86     837.90    Brand_12
# 2                      Kane_and_Sons      11443.32    1437.55    Brand_21
# 3      FUENTES, RICHARDS AND JOHNSON      80754.48   11208.05    Brand 25
# 4                        cordova llc      73920.88    9542.55     Brand_3
# ...                              ...           ...        ...         ...
# 95045                  Jackson Group      57456.56    8436.10    Brand_14
# 95046                       Hill LLC      20418.15    1554.78     Brand_6
# 95047               Mclaughlin-Smith      17020.80    1313.53     Brand_7
# 95048            Gaines-Mckinney Ltd      31093.44    4168.63    Brand 17
# 95049                   GRIFFIN-YORK      85655.72    4743.85    Brand_14
#
#                     VendorName_clean
# 0                      Keith Sanchez
# 1                    Harrington Gray
# 2                      Kane And Sons
# 3      Fuentes, Richards And Johnson
# 4                        Cordova Llc
# ...                              ...
# 95045                  Jackson Group
# 95046                       Hill Llc
# 95047               Mclaughlin Smith
# 95048            Gaines Mckinney Ltd
# 95049                   Griffin York
#
# [95050 rows x 16 columns]
# -------------------------------------------------- vendor_invoice --------------------------------------------------
#      VendorNumber                 VendorName  Quantity      Dollars  \
# 0            V039                 Lara_Group  212337.0  36910458.55
# 1            V029                Mcdaniel-Le  199724.0  34347016.44
# 2            V015          Wolfe-Murillo Ltd  217758.0  37421596.92
# 3            V008               MCDONALD LTD  207022.0  35699470.20
# 4            V021           BANKS-MONTGOMERY  199468.0  34367702.77
# ...           ...                        ...       ...          ...
# 5195         V001  Pratt, Parrish and Reilly  202883.0  34883264.26
# 5196         V001  Pratt, Parrish and Reilly  202883.0  34883264.26
# 5197         V017            Harrington-Gray  214295.0  36857451.30
# 5198         None               Long-Roberts  207956.0  35895805.88
# 5199         V029                Mcdaniel-Le  199724.0  34347016.44
#
#         Freight   InvoiceDate        PODate       PayDate PONumber  Approval  \
# 0     273137.39  Apr 08, 2024    07/26/2024    2024-10-28  PO-8697   Pending
# 1     501466.44    2024-05-30    03/21/2024    09/07/2024  PO-1759  Approved
# 2     508933.72      30/04/24  Jan 30, 2024  Dec 09, 2024  PO-7385  Approved
# 3     560481.68  Mar 28, 2024  Jan 30, 2024  Feb 04, 2024  PO-0551  Approved
# 4     457090.45      28/12/24  Oct 31, 2024      17/09/24  PO-5749  Approved
# ...         ...           ...           ...           ...      ...       ...
# 5195  216276.24    06/01/2024    2024-03-28    2024-02-18  PO-1810   Pending
# 5196  216276.24    06/01/2024    2024-03-28    2024-02-18  PO-1810   Pending
# 5197  353831.53    07/19/2024      23/09/24      10/12/24  PO-5843  Approved
# 5198  341010.16  Feb 02, 2024    11/17/2024    2024-04-01  PO-5662  Approved
# 5199  501466.44    2024-05-30    03/21/2024    09/07/2024  PO-1759  Approved
#
#      PayDate_clean PODate_clean           VendorName_clean
# 0       2024-07-17   2024-03-04                 Lara Group
# 1       2024-11-24   2024-06-09                Mcdaniel Le
# 2       2024-05-26   2024-05-14          Wolfe Murillo Ltd
# 3       2024-07-23   2024-04-20               Mcdonald Ltd
# 4       2024-01-18   2024-07-25           Banks Montgomery
# ...            ...          ...                        ...
# 5195    2024-06-02   2024-10-24  Pratt, Parrish And Reilly
# 5196    2024-08-18   2024-07-20  Pratt, Parrish And Reilly
# 5197    2024-06-28   2024-11-23            Harrington Gray
# 5198    2024-05-24   2024-11-17               Long Roberts
# 5199    2024-11-21   2024-09-03                Mcdaniel Le
#
# [5200 rows x 13 columns]

# %% [markdown]
# **Data Cleaning -- Duplicates**

# %%
for name, df in dfs.items():
    df.drop_duplicates(keep='first')
    print(df.shape)
# Out:
# (8000, 11)
# (8000, 11)
# (32300, 21)
# (12000, 11)
# (95050, 16)
# (5200, 13)

# %% [markdown]
# **Data Cleaning -- Missing Values**

# %%
## CHECKING NON-NULL COUNTS ACROSS ALL TABLES

#Approach 1: Recommended
for name, df in dfs.items():
    print(f"\n--- {name} ---")
    df.info()  # .info() is a method and needs to be called on the dataframe

#Approach 2: Ad-hoc for the required table
#for col_name in dfs['purchases'].columns: 
#    null_count = dfs['purchases'][col_name].isna().sum()
#    print(f"{col_name}: {null_count}") ##
# Out:
# --- begin_inventory ---
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8000 entries, 0 to 7999
# Data columns (total 11 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   InventoryId      8000 non-null   int64
#  1   Store            8000 non-null   object
#  2   City             8000 non-null   object
#  3   Brand            8000 non-null   object
#  4   Description      8000 non-null   object
#  5   Size             8000 non-null   object
#  6   onHand           8000 non-null   int64
#  7   Price            8000 non-null   float64
#  8   startDate        8000 non-null   object
#  9   startDate_clean  8000 non-null   datetime64[ns]
#  10  Brand_clean      8000 non-null   object
# dtypes: datetime64[ns](1), float64(1), int64(2), object(7)
# memory usage: 687.6+ KB
#
# --- end_inventory ---
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8000 entries, 0 to 7999
# Data columns (total 11 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   InventoryId    8000 non-null   int64
#  1   Store          8000 non-null   object
#  2   City           8000 non-null   object
#  3   Brand          8000 non-null   object
#  4   Description    8000 non-null   object
#  5   Size           8000 non-null   object
#  6   onHand         8000 non-null   int64
#  7   Price          8000 non-null   float64
#  8   endDate        8000 non-null   object
#  9   endDate_clean  8000 non-null   datetime64[ns]
#  10  Brand_clean    8000 non-null   object
# dtypes: datetime64[ns](1), float64(1), int64(2), object(7)
# memory usage: 687.6+ KB
#
# --- purchases ---
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 32300 entries, 0 to 32299
# Data columns (total 21 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   InventoryId          32300 non-null  int64
#  1   Store                32300 non-null  object
#  2   Brand                32300 non-null  object
#  3   Description          32300 non-null  object
#  4   Size                 32300 non-null  object
#  5   VendorNumber         32300 non-null  object
#  6   VendorName           32300 non-null  object
#  7   PONumber             32300 non-null  object
#  8   PODate               32300 non-null  object
#  9   ReceivingDate        32300 non-null  object
#  10  InvoiceDate          32300 non-null  object
#  11  PayDate              32300 non-null  object
#  12  PurchasePrice        32145 non-null  float64
#  13  Quantity             32148 non-null  float64
#  14  Classification       32300 non-null  object
#  15  Dollars              32300 non-null  float64
#  16  ReceivingDate_clean  32300 non-null  datetime64[ns]
#  17  InvoiceDate_clean    32300 non-null  datetime64[ns]
#  18  PayDate_clean        32300 non-null  datetime64[ns]
#  19  Brand_clean          32300 non-null  object
#  20  VendorName_clean     32300 non-null  object
# dtypes: datetime64[ns](3), float64(3), int64(1), object(14)
# memory usage: 5.2+ MB
#
# --- purchase_prices ---
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 12000 entries, 0 to 11999
# Data columns (total 11 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Brand             12000 non-null  object
#  1   Description       12000 non-null  object
#  2   Price             12000 non-null  float64
#  3   Size              12000 non-null  object
#  4   Volume            12000 non-null  int64
#  5   Classification    12000 non-null  object
#  6   PurchasePrice     12000 non-null  float64
#  7   VendorNumber      12000 non-null  object
#  8   VendorName        12000 non-null  object
#  9   Brand_clean       12000 non-null  object
#  10  VendorName_clean  12000 non-null  object
# dtypes: float64(2), int64(1), object(8)
# memory usage: 1.0+ MB
#
# --- sales ---
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 95050 entries, 0 to 95049
# Data columns (total 16 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   InventoryId       95050 non-null  int64
#  1   Store             95050 non-null  object
#  2   Brand             95050 non-null  object
#  3   Description       95050 non-null  object
#  4   Size              95050 non-null  object
#  5   SalesQuantity     94700 non-null  float64
#  6   SalesPrice        94700 non-null  float64
#  7   SalesDate         95050 non-null  object
#  8   Volume            95050 non-null  int64
#  9   Classification    95050 non-null  object
#  10  VendorNo          95050 non-null  object
#  11  VendorName        95050 non-null  object
#  12  SalesDollars      95050 non-null  float64
#  13  ExciseTax         95050 non-null  float64
#  14  Brand_clean       95050 non-null  object
#  15  VendorName_clean  95050 non-null  object
# dtypes: float64(4), int64(2), object(10)
# memory usage: 11.6+ MB
#
# --- vendor_invoice ---
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5200 entries, 0 to 5199
# Data columns (total 13 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   VendorNumber      5200 non-null   object
#  1   VendorName        5200 non-null   object
#  2   Quantity          5200 non-null   float64
#  3   Dollars           5200 non-null   float64
#  4   Freight           5200 non-null   float64
#  5   InvoiceDate       5200 non-null   object
#  6   PODate            5200 non-null   object
#  7   PayDate           5200 non-null   object
#  8   PONumber          5200 non-null   object
#  9   Approval          5200 non-null   object
#  10  PayDate_clean     5200 non-null   datetime64[ns]
#  11  PODate_clean      5200 non-null   datetime64[ns]
#  12  VendorName_clean  5200 non-null   object
# dtypes: datetime64[ns](2), float64(3), object(8)
# memory usage: 528.3+ KB

# %%
# FILLING MISSING VALUES WITH '0' AS <1% 

dfs['vendor_invoice']['VendorNumber'] = dfs['vendor_invoice']['VendorNumber'].astype(str).str.replace("None","Unknown")
dfs['begin_inventory']['Description'] = dfs['begin_inventory']['Description'].astype(str).str.replace("None","Unknown")
dfs['sales'].fillna(0,inplace = True)
dfs['purchases'].fillna(0,inplace = True)

# %% [markdown]
# **Misc -- Data Checks**

# %%
#checking cnnecting link between tables
pd.read_sql_query("SELECT * FROM purchase_prices AS p JOIN vendor_invoice as v ON CAST(p.VendorNumber AS TEXT) = CAST(v.VendorNumber AS TEXT)", engine)['VendorNumber'].nunique()
# Out:
# VendorNumber    40
# VendorNumber    40
# dtype: int64

# %%
# Step 1: Check how many IDs overlap
set_b = set(pd.read_sql("SELECT InventoryId FROM begin_inventory", engine)["InventoryId"])
set_e = set(pd.read_sql("SELECT InventoryId FROM end_inventory", engine)["InventoryId"])

print("Overlap %:", len(set_b & set_e) / len(set_b) * 100)

# Step 2: Check data types
print(pd.read_sql("PRAGMA table_info(begin_inventory)", engine))
print(pd.read_sql("PRAGMA table_info(end_inventory)", engine))
# Out:
# Overlap %: 0.0
#    cid         name    type  notnull dflt_value  pk
# 0    0  InventoryId  BIGINT        0       None   0
# 1    1        Store    TEXT        0       None   0
# 2    2         City    TEXT        0       None   0
# 3    3        Brand    TEXT        0       None   0
# 4    4  Description    TEXT        0       None   0
# 5    5         Size    TEXT        0       None   0
# 6    6       onHand  BIGINT        0       None   0
# 7    7        Price   FLOAT        0       None   0
# 8    8    startDate    TEXT        0       None   0
#    cid         name    type  notnull dflt_value  pk
# 0    0  InventoryId  BIGINT        0       None   0
# 1    1        Store    TEXT        0       None   0
# 2    2         City    TEXT        0       None   0
# 3    3        Brand    TEXT        0       None   0
# 4    4  Description    TEXT        0       None   0
# 5    5         Size    TEXT        0       None   0
# 6    6       onHand  BIGINT        0       None   0
# 7    7        Price   FLOAT        0       None   0
# 8    8      endDate    TEXT        0       None   0

# %%
# Step 1: Check how many Vendor IDs overlap
set_v = set(pd.read_sql("SELECT VendorNumber FROM vendor_invoice", engine)["VendorNumber"])
set_p = set(pd.read_sql("SELECT VendorNumber FROM purchase_prices", engine)["VendorNumber"])

print("Overlap %:", len(set_v & set_p) / len(set_p) * 100)

# Step 2: Check data types
print(pd.read_sql("PRAGMA table_info(purchase_prices)", engine))
print(pd.read_sql("PRAGMA table_info(vendor_invoice)", engine))
# Out:
# Overlap %: 97.5609756097561
#    cid            name    type  notnull dflt_value  pk
# 0    0           Brand    TEXT        0       None   0
# 1    1     Description    TEXT        0       None   0
# 2    2           Price   FLOAT        0       None   0
# 3    3            Size    TEXT        0       None   0
# 4    4          Volume  BIGINT        0       None   0
# 5    5  Classification    TEXT        0       None   0
# 6    6   PurchasePrice   FLOAT        0       None   0
# 7    7    VendorNumber    TEXT        0       None   0
# 8    8      VendorName    TEXT        0       None   0
#    cid          name    type  notnull dflt_value  pk
# 0    0  VendorNumber    TEXT        0       None   0
# 1    1    VendorName    TEXT        0       None   0
# 2    2   InvoiceDate    TEXT        0       None   0
# 3    3      PONumber    TEXT        0       None   0
# 4    4        PODate    TEXT        0       None   0
# 5    5       PayDate    TEXT        0       None   0
# 6    6      Quantity  BIGINT        0       None   0
# 7    7       Dollars   FLOAT        0       None   0
# 8    8       Freight   FLOAT        0       None   0
# 9    9      Approval    TEXT        0       None   0

# %% [markdown]
# **Final Data - Post Cleaning**

# %%
for name, df in dfs.items():  
    print('-'*50, name, '-'*50)
    display(df)
# Out:
# -------------------------------------------------- begin_inventory --------------------------------------------------
#       InventoryId     Store               City     Brand  Description    Size  \
# 0          100000   Store_7       Patrickhaven  Brand_16  Product_132  Medium
# 1          100001  Store_15        Kramerhaven   Brand_2   Product_66  Medium
# 2          100002  Store_11          Smithside  Brand_15  Product_120   Small
# 3          100003   Store_8  East Brittneyview  Brand_13  Product_124  Medium
# 4          100004   Store_7        Kramerhaven  Brand_13  Product_161   Large
# ...           ...       ...                ...       ...          ...     ...
# 7995       107995   Store_2        Port Vernon  Brand_23  Product_151  Medium
# 7996       107996   Store_6       Port Michael  Brand_23   Product_25  Medium
# 7997       107997  Store_18         Lake Emily   Brand_7   Product_37   Small
# 7998       107998   Store_9           Dayhaven  Brand_21  Product_112   Small
# 7999       107999   Store_6           Dayhaven   Brand_9    Product_2   Large
#
#       onHand   Price     startDate startDate_clean Brand_clean
# 0        513   59.99  Apr 07, 2024      2024-04-07    Brand_16
# 1        135  182.61      03/03/24      2024-03-03     Brand_2
# 2        628  150.98      14/01/24      2024-01-14    Brand_15
# 3        408  156.96  Mar 07, 2024      2024-03-07    Brand_13
# 4        120   83.44    2024-06-17      2024-06-17    Brand_13
# ...      ...     ...           ...             ...         ...
# 7995      38  242.89  Oct 03, 2024      2024-10-03    Brand_23
# 7996     618   23.22  Apr 08, 2024      2024-04-08    Brand_23
# 7997     611  237.01      05/02/24      2024-02-05     Brand_7
# 7998     783   48.22  Jan 04, 2024      2024-01-04    Brand_21
# 7999     740  100.48    09/18/2024      2024-09-18     Brand_9
#
# [8000 rows x 11 columns]
# -------------------------------------------------- end_inventory --------------------------------------------------
#       InventoryId     Store                City     Brand  Description  \
# 0          200000  Store_12          East Sarah  Brand_12   Product_41
# 1          200001  Store_16         Port Vernon  Brand_15   Product_77
# 2          200002  Store_18           Smithside  Brand_18  Product_105
# 3          200003   Store_5            Dayhaven  Brand_23   Product_49
# 4          200004  Store_16  Port Daniellehaven   Brand_1   Product_71
# ...           ...       ...                 ...       ...          ...
# 7995       207995  Store_15           Penamouth  Brand_10  Product_125
# 7996       207996  Store_16         Gibsonmouth   Brand_5  Product_180
# 7997       207997  Store_10          Rivasmouth  Brand_22  Product_169
# 7998       207998   Store_4           Penamouth  Brand_11   Product_91
# 7999       207999  Store_11   East Brittneyview  Brand_17   Product_88
#
#         Size  onHand   Price       endDate endDate_clean Brand_clean
# 0     Medium     730   77.30    2024-08-22    2024-08-22    Brand_12
# 1      Large      75   98.68      02/09/24    2024-09-02    Brand_15
# 2      Small     201  252.74    04/13/2024    2024-04-13    Brand_18
# 3      Large     200    9.31    2024-06-08    2024-06-08    Brand_23
# 4      Small     767   84.27  Mar 01, 2024    2024-03-01     Brand_1
# ...      ...     ...     ...           ...           ...         ...
# 7995   Large     541  222.64      26/04/24    2024-04-26    Brand_10
# 7996   Small     754  199.96      24/09/24    2024-09-24     Brand_5
# 7997   Small     729   79.09  Oct 15, 2024    2024-10-15    Brand_22
# 7998   Small     323   97.83    2024-03-16    2024-03-16    Brand_11
# 7999  Medium     602  135.28    02/28/2024    2024-02-28    Brand_17
#
# [8000 rows x 11 columns]
# -------------------------------------------------- purchases --------------------------------------------------
#        InventoryId     Store     Brand  Description    Size VendorNumber  \
# 0           300000   Store_6  brand_25  Product_145  Medium         V004
# 1           300001   Store_2   Brand_8   Product_48   Large         V023
# 2           300002   Store_9  brand_25   Product_78   Small         V009
# 3           300003   Store_8     BRD-2  Product_122   Small         V040
# 4           300004  Store_15   Brand_9    Product_9   Large         V024
# ...            ...       ...       ...          ...     ...          ...
# 32025       301230   Store_8  Brand_25  Product_137   Large         V004
# 32026       317721  Store_17  Brand_22  Product_140   Large         V021
# 32027       304839  Store_17    BRD-13  Product_143   Large         V018
# 32028       330591  Store_14  brand_24   Product_96  Medium         V015
# 32029       311938   Store_3  Brand_18  Product_122   Small         V018
#
#                       VendorName    PONumber        PODate ReceivingDate  ...  \
# 0      Yoder, Boyle and Williams  PO-5832-pA      24/03/24  Jul 30, 2024  ...
# 1             Smith and Sons Ltd  PO-1549-Kb    11/01/2024    2024-01-29  ...
# 2                    Ward-Wilson  PO-9768-Tx    2024-08-10    05/21/2024  ...
# 3                     sawyer inc  PO-3079-TS    10/15/2024      13/11/24  ...
# 4         Weaver, Ruiz and Bates  PO-0216-Iu  Jan 30, 2024  Mar 05, 2024  ...
# ...                          ...         ...           ...           ...  ...
# 32025  Yoder, Boyle and Williams  PO-7421-oG      14/01/24    08/08/2024  ...
# 32026               GIBSON-RAMOS  PO-4718-vZ    10/19/2024    2024-10-20  ...
# 32027                Hogan Group  PO-8563-ww    2024-01-10    2024-09-16  ...
# 32028            Hart-Chavez Ltd  PO-1647-QN      20/11/24  Apr 24, 2024  ...
# 32029                Hogan Group  PO-5952-sn    2024-05-22    2024-04-21  ...
#
#             PayDate PurchasePrice  Quantity  Classification    Dollars  \
# 0        2024-03-06        268.91      24.0               B    6453.84
# 1          07/09/24        224.45     844.0               B  189435.80
# 2      May 31, 2024        129.49     239.0               A   30948.11
# 3      Jan 23, 2024         68.29     521.0               B   35579.09
# 4        2024-11-10        273.52     878.0               A  240150.56
# ...             ...           ...       ...             ...        ...
# 32025    2024-07-24         50.80     836.0               A   42468.80
# 32026    2024-11-30        232.49     488.0               A  113455.12
# 32027  Mar 18, 2024         47.85     839.0               A   40146.15
# 32028    03/03/2024        215.97     438.0               A   94594.86
# 32029  May 24, 2024         40.94     137.0               A    5608.78
#
#        ReceivingDate_clean InvoiceDate_clean PayDate_clean Brand_clean  \
# 0               2024-07-30        2024-06-28    2024-03-06    Brand_25
# 1               2024-01-29        2024-02-20    2024-09-07     Brand_8
# 2               2024-05-21        2024-07-16    2024-05-31    Brand_25
# 3               2024-11-13        2024-11-28    2024-01-23     Brand_2
# 4               2024-03-05        2024-05-17    2024-11-10     Brand_9
# ...                    ...               ...           ...         ...
# 32025           2024-08-08        2024-05-29    2024-07-24    Brand_25
# 32026           2024-10-20        2024-11-22    2024-11-30    Brand_22
# 32027           2024-09-16        2024-12-21    2024-03-18    Brand_13
# 32028           2024-04-24        2024-07-31    2024-03-03    Brand_24
# 32029           2024-04-21        2024-09-05    2024-05-24    Brand_18
#
#                 VendorName_clean
# 0      Yoder, Boyle And Williams
# 1             Smith And Sons Ltd
# 2                    Ward Wilson
# 3                     Sawyer Inc
# 4         Weaver, Ruiz And Bates
# ...                          ...
# 32025  Yoder, Boyle And Williams
# 32026               Gibson Ramos
# 32027                Hogan Group
# 32028            Hart Chavez Ltd
# 32029                Hogan Group
#
# [32030 rows x 21 columns]
# -------------------------------------------------- purchase_prices --------------------------------------------------
#           Brand  Description   Price   Size  Volume Classification  \
# 0      Brand_17  Product_105   31.90  Large   10640              A
# 1      Brand_16  Product_110  328.05  Small    4863              A
# 2      Brand_13   Product_79  254.32  Large   14815              A
# 3      Brand_18   Product_70   74.81  Small    8468              A
# 4       Brand_2  Product_153   77.17  Large    8798              C
# ...         ...          ...     ...    ...     ...            ...
# 11995   Brand_9  Product_155   17.82  Small   13205              A
# 11996  Brand_10  Product_174   19.80  Large   12595              B
# 11997   Brand_5   Product_52  252.86  Small    9463              C
# 11998  Brand_21  Product_141   66.94  Small    7204              B
# 11999  Brand_19  Product_156  274.21  Large    1828              C
#
#        PurchasePrice VendorNumber                    VendorName Brand_clean  \
# 0             162.36         V031   Johnson, Jones and Martinez    Brand_17
# 1              69.10         V025                  Thomas Group    Brand_16
# 2             164.88         V030  Wallace, Young and Rodriguez    Brand_13
# 3             265.02         V033                   Gardner Inc    Brand_18
# 4             249.02         V014                  Anderson Ltd     Brand_2
# ...              ...          ...                           ...         ...
# 11995          15.02         V007                   Lewis-Davis     Brand_9
# 11996         221.78         V022    Johnson, Pace and Anderson    Brand_10
# 11997         190.31         V028                   Gardner Inc     Brand_5
# 11998          95.71         V040     Thomas, Morris and Murray    Brand_21
# 11999         174.23         V014                  Thomas Group    Brand_19
#
#                    VendorName_clean
# 0       Johnson, Jones And Martinez
# 1                      Thomas Group
# 2      Wallace, Young And Rodriguez
# 3                       Gardner Inc
# 4                      Anderson Ltd
# ...                             ...
# 11995                   Lewis Davis
# 11996    Johnson, Pace And Anderson
# 11997                   Gardner Inc
# 11998     Thomas, Morris And Murray
# 11999                  Thomas Group
#
# [12000 rows x 11 columns]
# -------------------------------------------------- sales --------------------------------------------------
#        InventoryId     Store     Brand  Description    Size  SalesQuantity  \
# 0           400000   Store_5  Brand 16   Product_81   Small          468.0
# 1           400001   Store_3   brand_9   Product_23  Medium          254.0
# 2           400002   Store_2  Brand 14  Product_149  Medium          422.0
# 3           400003  Store_18  brand_20  Product_176  Medium           31.0
# 4           400004  Store_13  brand_15  Product_131  Medium          231.0
# ...            ...       ...       ...          ...     ...            ...
# 95020       479625   Store_4  Brand 13  Product_151   Small          455.0
# 95021       411795   Store_4    BRD-16  Product_125   Small          144.0
# 95022       485200  Store_11   Brand 3   Product_70  Medium          215.0
# 95023       442775  Store_14  Brand_21  Product_179   Large           30.0
# 95024       459703  Store_14  Brand 23  Product_112   Small          155.0
#
#        SalesDollars  SalesPrice     SalesDate  Volume Classification  \
# 0          53787.63       27.80    2024-06-27    2168              A
# 1          73591.06      344.07  Jun 06, 2024    4203              A
# 2          51853.53      228.58  Jul 26, 2024    7965              A
# 3           5273.03      385.70      13/04/24    6358              C
# 4          67543.52      212.74    2024-02-20    4296              C
# ...             ...         ...           ...     ...            ...
# 95020        791.10       95.63    2024-06-16    6652              C
# 95021       6430.05       73.62  May 04, 2024    3132              A
# 95022        678.64      332.97    02/15/2024   11362              B
# 95023       3676.29      176.13    2024-02-09    7242              C
# 95024      41172.34      265.15  Nov 19, 2024   11522              A
#
#        ExciseTax VendorNo                   VendorName Brand_clean  \
# 0          44.37     V028              Bowman and Sons    Brand 16
# 1          15.61     V037  JOHNSON, JONES AND MARTINEZ     Brand_9
# 2           5.16     V012                 Gardner Inc.    Brand 14
# 3           8.47     V025             Boyle-Prince Ltd    Brand_20
# 4          59.72     V032                GREEN-WOODARD    Brand_15
# ...          ...      ...                          ...         ...
# 95020      52.22     V023           Smith and Sons Ltd    Brand 13
# 95021      86.46     V020                 ANDERSON LTD    Brand_16
# 95022      39.91     V026  BALLARD, RAMIREZ AND CARTER     Brand 3
# 95023      86.00     V008   JOHNSON, PACE AND ANDERSON    Brand_21
# 95024      80.66     V022         Hughes-Rodriguez Ltd    Brand 23
#
#                   VendorName_clean
# 0                  Bowman And Sons
# 1      Johnson, Jones And Martinez
# 2                     Gardner Inc
# 3                 Boyle Prince Ltd
# 4                    Green Woodard
# ...                            ...
# 95020           Smith And Sons Ltd
# 95021                 Anderson Ltd
# 95022  Ballard, Ramirez And Carter
# 95023   Johnson, Pace And Anderson
# 95024         Hughes Rodriguez Ltd
#
# [95025 rows x 16 columns]
# -------------------------------------------------- vendor_invoice --------------------------------------------------
#      VendorNumber                      VendorName   InvoiceDate PONumber  \
# 0            V006    Wallace, Young and Rodriguez    07/19/2024  PO-5191
# 1            V014       Yoder, Boyle and Williams    02/28/2024  PO-6825
# 2            V025          Yang,_Jones_and_Miller    2024-09-21  PO-0426
# 3            V015      JOHNSON, PACE AND ANDERSON  Oct 10, 2024  PO-0826
# 4            V007                  ENGLISH-LAWSON  Sep 17, 2024  PO-6597
# ...           ...                             ...           ...      ...
# 5195         V015               Villanueva-Flores      05/10/24  PO-5978
# 5196         V013  rodriguez, ferguson and murphy      20/02/24  PO-9678
# 5197         V003                Parker Group Ltd    2024-09-15  PO-0983
# 5198         V022                   zimmerman llc      25/04/24  PO-8776
# 5199         V031                     Ward-Wilson    03/16/2024  PO-8489
#
#             PODate       PayDate  Quantity   Dollars  Freight  Approval  \
# 0     Sep 03, 2024    09/15/2024       758  28286.45  3103.04  Approved
# 1       11/04/2024    2024-12-14       715  83124.63   775.70  Approved
# 2         20/10/24      29/07/24      1498  14939.27  2087.73  Rejected
# 3       11/26/2024  Aug 18, 2024       838  76553.63   200.26   Pending
# 4         23/10/24    07/23/2024       897  36160.29  4107.63  Approved
# ...            ...           ...       ...       ...      ...       ...
# 5195    11/08/2024    01/27/2024      1521  28697.01  4664.58  Approved
# 5196    12/08/2024  Nov 18, 2024      1294  91874.68  3726.25  Approved
# 5197    11/27/2024  Jul 02, 2024      1287   8420.97  2006.77  Approved
# 5198  Feb 18, 2024      13/01/24      1583  12125.88  2341.11  Approved
# 5199      27/02/24    2024-12-12      1910  49162.73  3112.12   Pending
#
#      PayDate_clean PODate_clean                VendorName_clean
# 0       2024-03-06   2024-03-24    Wallace, Young And Rodriguez
# 1       2024-09-07   2024-01-11       Yoder, Boyle And Williams
# 2       2024-05-31   2024-08-10          Yang, Jones And Miller
# 3       2024-01-23   2024-10-15      Johnson, Pace And Anderson
# 4       2024-11-10   2024-01-30                  English Lawson
# ...            ...          ...                             ...
# 5195    2024-07-10   2024-10-20               Villanueva Flores
# 5196    2024-02-10   2024-11-10  Rodriguez, Ferguson And Murphy
# 5197    2024-07-08   2024-06-15                Parker Group Ltd
# 5198    2024-10-22   2024-03-21                   Zimmerman Llc
# 5199    2024-09-26   2024-12-28                     Ward Wilson
#
# [5200 rows x 13 columns]

# %% [markdown]
# **Storing the Cleaned Tables back into CSVs**

# %%
output_folder = "cleaned_data"
os.makedirs(output_folder, exist_ok=True)

for name, df in dfs.items():
    output_path = f"{output_folder}/{name}.csv"  # output_path = cleaned_data/ table_name.csv
    df.to_csv(output_path, index=False)
    print(f"Saved: {output_path} ({df.shape[0]} rows, {df.shape[1]} columns)")
# Out:
# Saved: cleaned_data/begin_inventory.csv (8000 rows, 11 columns)
# Saved: cleaned_data/end_inventory.csv (8000 rows, 11 columns)
# Saved: cleaned_data/purchases.csv (32300 rows, 21 columns)
# Saved: cleaned_data/purchase_prices.csv (12000 rows, 11 columns)
# Saved: cleaned_data/sales.csv (95050 rows, 16 columns)
# Saved: cleaned_data/vendor_invoice.csv (5200 rows, 13 columns)

# %% [markdown]
# **Understanding the Info in each table**
#
# - The begin_inventory and end_inventory tables contain inventory data at the start and end of the year, which is not relevant for analyzing vendor behavior.
# - Therefore, these tables can be excluded from the analysis.
# - Next, we will examine how vendor-related data is distributed across other tables.
#
# -------
#
# - Purcahes: info about the procurements made by the Vendors from the company along with Trasnaction Details (Invoice Dates, Payment Dates, Transaction Value i.e. Dollars), Product (Brand) Prices ($), Quantity procured
# - Purchase_Prices: The purchase price column is derived from the purchase_prices table, which provides product-wise actual and purchase prices. In addition to the Product, Brand, it provides info like Volume.
# - Vendor_Invoice: aggregates data from the purchases table, summarizing Quantity and Dollar amounts, along with an additional column for Freight
# - Sales: contains the sales transactions for the year - Product Info, Brands purchased by vendors, Volume, SalesQuantity, SalesPrice, SalesDollars (revenue earned)
#
# ------
#
# As the data that we need for analysis is distributed in different tables, we need to create a summary table containing:
# - purchase transactions made by vendors
# - sales transaction data
# - freight costs for each vendor
# - actual product prices from vendors

# %%
wb1 = dfs['purchase_prices'][dfs['purchase_prices']['VendorNumber'] == 'V017'].sort_values('VendorName_clean')
wb1
# Out:
#           Brand  Description   Price    Size  Volume Classification  \
# 6092   Brand_16   Product_47  267.45  Medium   10874              B
# 18931  Brand_15  Product_129  179.55  Medium   12650              B
# 8096    Brand_5  Product_162   98.95  Medium    2920              A
# 2767   Brand_11    Product_3  278.20   Small    9039              B
# 13881   Brand_7   Product_40  258.67  Medium   11173              A
# ...         ...          ...     ...     ...     ...            ...
# 1537   Brand_20    Product_1  225.13   Large    6698              B
# 18662   Brand_8  Product_114  102.77   Large    3191              C
# 7351    Brand_7   Product_74  106.01   Large   13404              B
# 13824   Brand_2   Product_53  173.68  Medium     311              A
# 17216  Brand_20  Product_171  316.63   Small    3037              A
#
#        PurchasePrice VendorNumber                     VendorName Brand_clean  \
# 6092          284.58         V017  Anderson, Hernandez and Brown    Brand_16
# 18931         231.74         V017  Anderson, Hernandez and Brown    Brand_15
# 8096           22.13         V017  Anderson, Hernandez and Brown     Brand_5
# 2767           86.39         V017  Anderson, Hernandez and Brown    Brand_11
# 13881         259.18         V017  Anderson, Hernandez and Brown     Brand_7
# ...              ...          ...                            ...         ...
# 1537           94.52         V017                Wright-Morrison    Brand_20
# 18662         226.37         V017                Wright-Morrison     Brand_8
# 7351          123.52         V017                Wright-Morrison     Brand_7
# 13824          42.84         V017                Wright-Morrison     Brand_2
# 17216         232.59         V017                Wright-Morrison    Brand_20
#
#                     VendorName_clean
# 6092   Anderson, Hernandez And Brown
# 18931  Anderson, Hernandez And Brown
# 8096   Anderson, Hernandez And Brown
# 2767   Anderson, Hernandez And Brown
# 13881  Anderson, Hernandez And Brown
# ...                              ...
# 1537                 Wright Morrison
# 18662                Wright Morrison
# 7351                 Wright Morrison
# 13824                Wright Morrison
# 17216                Wright Morrison
#
# [476 rows x 11 columns]

# %%
wb2 = dfs['vendor_invoice'][dfs['vendor_invoice']['VendorNumber'] == 'V017'].sort_values('VendorName_clean')
wb2['VendorName'].nunique()
wb2
# Out:
#      VendorNumber                     VendorName   InvoiceDate PONumber  \
# 1632         V017  Anderson, Hernandez and Brown    04/17/2024  PO-1296
# 2494         V017  Anderson, Hernandez and Brown  Jan 27, 2024  PO-0858
# 4609         V017  Anderson, Hernandez and Brown    04/20/2024  PO-1871
# 4472         V017  Anderson, Hernandez and Brown    2024-01-16  PO-0099
# 2521         V017    Brown, Fitzgerald and Evans    2024-04-04  PO-0169
# ...           ...                            ...           ...      ...
# 1176         V017  Williams,_Hickman_and_Nichols  Mar 12, 2024  PO-1873
# 1752         V017  Williams,_Hickman_and_Nichols  Nov 14, 2024  PO-6223
# 2558         V017  Williams,_Hickman_and_Nichols    2024-07-09  PO-8478
# 2169         V017                WRIGHT-MORRISON    2024-07-05  PO-7102
# 4030         V017                WRIGHT-MORRISON    2024-08-04  PO-6584
#
#             PODate       PayDate  Quantity   Dollars  Freight  Approval  \
# 1632    11/07/2024    02/04/2024       899  54095.64  1862.40   Pending
# 2494    01/28/2024    2024-01-19       719  12183.73  1829.41   Pending
# 4609    01/25/2024    11/21/2024        78   3797.98  3682.16   Pending
# 4472    07/31/2024  Nov 08, 2024      1376  53881.31  2521.67  Rejected
# 2521      01/10/24      08/01/24      1288  35630.84  3903.98  Approved
# ...            ...           ...       ...       ...      ...       ...
# 1176    09/04/2024      24/06/24      1973  24649.19  3863.60  Approved
# 1752  Jul 25, 2024    2024-12-12      1512  28167.94   690.18  Approved
# 2558    2024-08-31    08/28/2024       124  99953.43  3083.21  Approved
# 2169  Apr 29, 2024      22/03/24      1400  34106.92  1228.89  Approved
# 4030    2024-05-01    2024-02-16      1933  23482.27   329.68  Approved
#
#                    VendorName_clean PayDate_clean
# 1632  Anderson, Hernandez And Brown    2024-10-04
# 2494  Anderson, Hernandez And Brown    2024-09-04
# 4609  Anderson, Hernandez And Brown    2024-03-09
# 4472  Anderson, Hernandez And Brown    2024-10-26
# 2521    Brown, Fitzgerald And Evans    2024-05-21
# ...                             ...           ...
# 1176  Williams, Hickman And Nichols    2024-12-01
# 1752  Williams, Hickman And Nichols    2024-07-12
# 2558  Williams, Hickman And Nichols    2024-09-05
# 2169                Wright Morrison    2024-01-09
# 4030                Wright Morrison    2024-01-17
#
# [127 rows x 12 columns]

# %%
set(wb1.columns) & set(wb2.columns)
# Out:
# {'VendorName', 'VendorName_clean', 'VendorNumber'}
